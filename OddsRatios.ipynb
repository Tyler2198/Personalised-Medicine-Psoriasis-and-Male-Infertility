# %% [markdown]
# ## Psoriasis - Infertility/NonInfertility

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from statsmodels.stats.proportion import proportion_confint
from statsmodels.stats.proportion import proportions_ztest
import statsmodels.api as sm

# %%
df = pd.read_excel("/Users/kryptonempyrean/Desktop/Tesi Material/OneDrive_1_08-09-2024/Psoriasis_2017_Erez_Data2_Coded codifica in corso.xlsx", sheet_name="PsoriasisPanel")

# %%
df.head()
# Out:
#          New_ID         Match  Match_N    Start_D  DiagYear  kodClc  \
# 0  1.203916e+09  1.190652e+13      2.0 2005-08-03    2005.0  5241.0
# 1  7.935922e+10  1.190652e+13      2.0 2005-08-03    2005.0  5241.0
# 2  1.211328e+10  1.190733e+13      2.0 2003-10-12    2003.0  3343.0
# 3  8.423707e+10  1.190733e+13      2.0 2003-10-12    2003.0  3343.0
# 4  1.240091e+09  1.190930e+13      2.0 2009-06-30    2009.0  3047.0
#
#    GroupCode  GroupName Tuberculosis Tuberculosis s/p  ... CntBikChildConsult  \
# 0        1.0  Psoriasis          NaN              NaN  ...                  0
# 1        0.0    Control          NaN              NaN  ...                  0
# 2        1.0  Psoriasis          NaN              NaN  ...                  0
# 3        0.0    Control          NaN              NaN  ...                  0
# 4        1.0  Psoriasis          NaN              NaN  ...                  0
#
#   CntBikGastro CntBikOrtopedic CntBikEyes CntBikEar CntBikPrimary  DaysIsp  \
# 0            0               0          0         0             0      NaN
# 1            0               0          0         0             0      NaN
# 2            0               0          0         0             0      NaN
# 3            0               0          0         0             0      NaN
# 4            0               0          0         0             0      NaN
#
#   KabalotRagil KabalotMiun  Unnamed: 304
# 0            0           0           NaN
# 1            0           0           NaN
# 2            0           0           NaN
# 3            0           0           NaN
# 4            0           0           NaN
#
# [5 rows x 305 columns]

# %%
df = df.iloc[:280450]

# %%
columns = pd.read_excel("/Users/kryptonempyrean/Desktop/Tesi Material/OneDrive_1_08-09-2024/Psoriasis_2017_Erez_Data2_Coded codifica in corso.xlsx", sheet_name="Foglio1", header=None)
columns = columns[1].tolist()

comorbidities = columns[:142]
selected_comorbidities = sorted(set(df.columns.tolist()) & set(comorbidities),  key = df.columns.tolist().index)
selected_comorbidities.remove("Psoriasis")

selected_columns = ['date_of_birth','GroupName','age','sex','Start_D','DiagYear', "Infertility ", "Psoriasis"] + selected_comorbidities

# %%
data = df[selected_columns]
data
# Out:
#               date_of_birth  GroupName  age sex    Start_D  DiagYear  \
# 0       1906-05-15 00:00:00  Psoriasis   98   M 2005-08-03    2005.0
# 1       1906-06-15 00:00:00    Control   98   M 2005-08-03    2005.0
# 2       1907-06-15 00:00:00  Psoriasis   95   M 2003-10-12    2003.0
# 3       1907-05-14 00:00:00    Control   95   M 2003-10-12    2003.0
# 4       1909-01-01 00:00:00  Psoriasis  100   M 2009-06-30    2009.0
# ...                     ...        ...  ...  ..        ...       ...
# 280445  2016-06-03 00:00:00  Psoriasis    0   F 2017-11-14    2017.0
# 280446  2017-01-03 00:00:00    Control    0   F 2017-05-15    2017.0
# 280447  2017-01-08 00:00:00  Psoriasis    0   F 2017-05-15    2017.0
# 280448  2017-01-08 00:00:00    Control    0   F 2017-11-21    2017.0
# 280449  2017-01-14 00:00:00  Psoriasis    0   F 2017-11-21    2017.0
#
#        Infertility  Psoriasis Tuberculosis Tuberculosis s/p  ... OncBone  \
# 0               NaN       NaN          NaN              NaN  ...     NaN
# 1               NaN       NaN          NaN              NaN  ...     NaN
# 2               NaN       NaN          NaN              NaN  ...     NaN
# 3               NaN       NaN          NaN              NaN  ...     NaN
# 4               NaN       NaN          NaN              NaN  ...     NaN
# ...             ...       ...          ...              ...  ...     ...
# 280445          NaN       NaN          NaN              NaN  ...     NaN
# 280446          NaN       NaN          NaN              NaN  ...     NaN
# 280447          NaN       NaN          NaN              NaN  ...     NaN
# 280448          NaN       NaN          NaN              NaN  ...     NaN
# 280449          NaN       NaN          NaN              NaN  ...     NaN
#
#        OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 0              NaN          NaN        NaN                 NaN
# 1              NaN          NaN        NaN                 NaN
# 2              NaN          NaN        NaN                 NaN
# 3              NaN          NaN        NaN                 NaN
# 4              NaN          NaN        NaN                 NaN
# ...            ...          ...        ...                 ...
# 280445         NaN          NaN        NaN                 NaN
# 280446         NaN          NaN        NaN                 NaN
# 280447         NaN          NaN        NaN                 NaN
# 280448         NaN          NaN        NaN                 NaN
# 280449         NaN          NaN        NaN                 NaN
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 0                     NaN                 NaN                  NaN      NaN
# 1                     NaN                 NaN                  NaN      NaN
# 2                     NaN                 NaN                  NaN      NaN
# 3                     NaN                 NaN                  NaN      NaN
# 4                     NaN                 NaN                  NaN      NaN
# ...                   ...                 ...                  ...      ...
# 280445                NaN                 NaN                  NaN      NaN
# 280446                NaN                 NaN                  NaN      NaN
# 280447                NaN                 NaN                  NaN      NaN
# 280448                NaN                 NaN                  NaN      NaN
# 280449                NaN                 NaN                  NaN      NaN
#
#        OncUnKnow
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 280445       NaN
# 280446       NaN
# 280447       NaN
# 280448       NaN
# 280449       NaN
#
# [280450 rows x 133 columns]

# %%
data = data[data.GroupName == 'Psoriasis']

# %%
data = data[data.sex == 'M']

# %%
# Converting date columns to datetime for comparison
data['Psoriasis'] = pd.to_datetime(data['Psoriasis'], errors='coerce')
data['Start_D'] = pd.to_datetime(data['Start_D'], errors='coerce')

# Set Psoriasis date based on group and availability
# If 'Psoriasis' is NaT and the group is "Psoriasis", use 'Start_D' as the proxy
data['Psoriasis'] = data.apply(
    lambda row: row['Start_D'] if pd.isna(row['Psoriasis']) and row['GroupName'] == 'Psoriasis' else row['Psoriasis'],
    axis=1
)

# %%
data
# Out:
#               date_of_birth  GroupName  age sex    Start_D  DiagYear  \
# 0       1906-05-15 00:00:00  Psoriasis   98   M 2005-08-03    2005.0
# 2       1907-06-15 00:00:00  Psoriasis   95   M 2003-10-12    2003.0
# 4       1909-01-01 00:00:00  Psoriasis  100   M 2009-06-30    2009.0
# 7       1909-05-01 00:00:00  Psoriasis   93   M 2003-04-24    2003.0
# 8       1909-06-09 00:00:00  Psoriasis   94   M 2004-09-20    2004.0
# ...                     ...        ...  ...  ..        ...       ...
# 138674  2016-03-15 00:00:00  Psoriasis    0   M 2017-03-14    2017.0
# 138676  2016-01-29 00:00:00  Psoriasis    1   M 2017-01-02    2017.0
# 138679  2016-01-30 00:00:00  Psoriasis    1   M 2017-03-30    2017.0
# 138681  2016-06-15 00:00:00  Psoriasis    0   M 2017-02-28    2017.0
# 138682  2016-10-13 00:00:00  Psoriasis    0   M 2017-01-13    2017.0
#
#        Infertility   Psoriasis Tuberculosis Tuberculosis s/p  ... OncBone  \
# 0               NaN 2005-08-03          NaN              NaN  ...     NaN
# 2               NaN 2003-10-12          NaN              NaN  ...     NaN
# 4               NaN 2009-06-30          NaN              NaN  ...     NaN
# 7               NaN 1999-11-16          NaN              NaN  ...     NaN
# 8               NaN 2004-02-23          NaN              NaN  ...     NaN
# ...             ...        ...          ...              ...  ...     ...
# 138674          NaN 2017-03-14          NaN              NaN  ...     NaN
# 138676          NaN 2017-01-02          NaN              NaN  ...     NaN
# 138679          NaN 2017-03-30          NaN              NaN  ...     NaN
# 138681          NaN 2017-02-28          NaN              NaN  ...     NaN
# 138682          NaN 2017-01-13          NaN              NaN  ...     NaN
#
#        OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 0              NaN          NaN        NaN                 NaN
# 2              NaN          NaN        NaN                 NaN
# 4              NaN          NaN        NaN                 NaN
# 7              NaN          NaN        NaN                 NaN
# 8              NaN          NaN        NaN                 NaN
# ...            ...          ...        ...                 ...
# 138674         NaN          NaN        NaN                 NaN
# 138676         NaN          NaN        NaN                 NaN
# 138679         NaN          NaN        NaN                 NaN
# 138681         NaN          NaN        NaN                 NaN
# 138682         NaN          NaN        NaN                 NaN
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 0                     NaN                 NaN                  NaN      NaN
# 2                     NaN                 NaN                  NaN      NaN
# 4                     NaN                 NaN                  NaN      NaN
# 7                     NaN                 NaN                  NaN      NaN
# 8                     NaN                 NaN                  NaN      NaN
# ...                   ...                 ...                  ...      ...
# 138674                NaN                 NaN                  NaN      NaN
# 138676                NaN                 NaN                  NaN      NaN
# 138679                NaN                 NaN                  NaN      NaN
# 138681                NaN                 NaN                  NaN      NaN
# 138682                NaN                 NaN                  NaN      NaN
#
#        OncUnKnow
# 0            NaN
# 2            NaN
# 4            NaN
# 7            NaN
# 8            NaN
# ...          ...
# 138674       NaN
# 138676       NaN
# 138679       NaN
# 138681       NaN
# 138682       NaN
#
# [69342 rows x 133 columns]

# %%
# Identify comorbidity columns, assuming they start from "Tuberculosis" onwards
comorbidity_columns = data.columns[data.columns.get_loc("Tuberculosis"):]

# Iterate through comorbidity columns to adjust dates
for column in comorbidity_columns:
    data[column] = pd.to_datetime(data[column], errors='coerce')
    # Replace the date with NaN if it occurs after the relevant reference date
    data[column] = data.apply(
        lambda row: (
            row[column] if pd.isna(row[column]) or (
                (row['GroupName'] == 'Psoriasis' and row[column] <= row['Psoriasis']) or
                (row['GroupName'] != 'Psoriasis' and row[column] <= row['Start_D'])
            ) else pd.NaT
        ), 
        axis=1
    )

# %%
# Convert Infertility column to datetime for comparison
data['Infertility '] = pd.to_datetime(data['Infertility '], errors='coerce')

# Filter patients who have infertility diagnosed after psoriasis or have NaN under infertility
data = data[
    (data['Infertility '].isna()) |  # Keep patients with no infertility diagnosis (control group)
    (data['Infertility '] > data['Psoriasis'])  # Keep patients with infertility diagnosed after psoriasis
]

# %%
data
# Out:
#               date_of_birth  GroupName  age sex    Start_D  DiagYear  \
# 0       1906-05-15 00:00:00  Psoriasis   98   M 2005-08-03    2005.0
# 2       1907-06-15 00:00:00  Psoriasis   95   M 2003-10-12    2003.0
# 4       1909-01-01 00:00:00  Psoriasis  100   M 2009-06-30    2009.0
# 7       1909-05-01 00:00:00  Psoriasis   93   M 2003-04-24    2003.0
# 8       1909-06-09 00:00:00  Psoriasis   94   M 2004-09-20    2004.0
# ...                     ...        ...  ...  ..        ...       ...
# 138674  2016-03-15 00:00:00  Psoriasis    0   M 2017-03-14    2017.0
# 138676  2016-01-29 00:00:00  Psoriasis    1   M 2017-01-02    2017.0
# 138679  2016-01-30 00:00:00  Psoriasis    1   M 2017-03-30    2017.0
# 138681  2016-06-15 00:00:00  Psoriasis    0   M 2017-02-28    2017.0
# 138682  2016-10-13 00:00:00  Psoriasis    0   M 2017-01-13    2017.0
#
#        Infertility   Psoriasis Tuberculosis Tuberculosis s/p  ... OncBone  \
# 0               NaT 2005-08-03          NaT              NaT  ...     NaT
# 2               NaT 2003-10-12          NaT              NaT  ...     NaT
# 4               NaT 2009-06-30          NaT              NaT  ...     NaT
# 7               NaT 1999-11-16          NaT              NaT  ...     NaT
# 8               NaT 2004-02-23          NaT              NaT  ...     NaT
# ...             ...        ...          ...              ...  ...     ...
# 138674          NaT 2017-03-14          NaT              NaT  ...     NaT
# 138676          NaT 2017-01-02          NaT              NaT  ...     NaT
# 138679          NaT 2017-03-30          NaT              NaT  ...     NaT
# 138681          NaT 2017-02-28          NaT              NaT  ...     NaT
# 138682          NaT 2017-01-13          NaT              NaT  ...     NaT
#
#        OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 0              NaT          NaT        NaT                 NaT
# 2              NaT          NaT        NaT                 NaT
# 4              NaT          NaT        NaT                 NaT
# 7              NaT          NaT        NaT                 NaT
# 8              NaT          NaT        NaT                 NaT
# ...            ...          ...        ...                 ...
# 138674         NaT          NaT        NaT                 NaT
# 138676         NaT          NaT        NaT                 NaT
# 138679         NaT          NaT        NaT                 NaT
# 138681         NaT          NaT        NaT                 NaT
# 138682         NaT          NaT        NaT                 NaT
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 0                     NaT                 NaT                  NaT      NaT
# 2                     NaT                 NaT                  NaT      NaT
# 4                     NaT                 NaT                  NaT      NaT
# 7                     NaT                 NaT                  NaT      NaT
# 8                     NaT                 NaT                  NaT      NaT
# ...                   ...                 ...                  ...      ...
# 138674                NaT                 NaT                  NaT      NaT
# 138676                NaT                 NaT                  NaT      NaT
# 138679                NaT                 NaT                  NaT      NaT
# 138681                NaT                 NaT                  NaT      NaT
# 138682                NaT                 NaT                  NaT      NaT
#
#        OncUnKnow
# 0            NaT
# 2            NaT
# 4            NaT
# 7            NaT
# 8            NaT
# ...          ...
# 138674       NaT
# 138676       NaT
# 138679       NaT
# 138681       NaT
# 138682       NaT
#
# [69022 rows x 133 columns]

# %%
# Create binary variable for presence of infertility (Infertility_Status)
data['Infertility_Status'] = np.where(data['Infertility '].notna(), 1, 0)

# List of comorbidity columns to include in the logistic regression
comorbidity_columns = data.columns[data.columns.get_loc("Tuberculosis"):]

# To store the results of each regression
results = []

# Loop through each comorbidity to perform logistic regression
for comorbidity in comorbidity_columns:
    # Create binary variable for presence of comorbidity
    data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)

    # Check for variability: skip if there is no or minimal variation
    count = data[comorbidity + '_status'].sum()
    if count == 0 or count == len(data) or count < 5:  # Skipping if too few positive cases
        continue

    # Define the independent variable (comorbidity) and the dependent variable (Infertility_Status)
    X = data[[comorbidity + '_status']]
    y = data['Infertility_Status']

    # Add an intercept to the independent variable
    X = sm.add_constant(X)

    try:
        # Fit the logistic regression model
        model = sm.Logit(y, X)
        result = model.fit(disp=False)

        # Calculate Odds Ratio for the comorbidity
        odds_ratio = np.exp(result.params[comorbidity + '_status'])
        ci = result.conf_int().loc[comorbidity + '_status']
        ci_odds_ratio = np.exp(ci)

        # Extract p-value for the comorbidity
        p_value = result.pvalues[comorbidity + '_status']

        # Append the results for the comorbidity
        results.append({
            'Comorbidity': comorbidity,
            'Odds Ratio': odds_ratio,
            '95% CI Lower': ci_odds_ratio[0],
            '95% CI Upper': ci_odds_ratio[1],
            'p-value': p_value
        })

    except np.linalg.LinAlgError:
        # Handle any singular matrix errors due to collinearity or insufficient data
        print(f"Skipping {comorbidity} due to singular matrix issue.")
        continue

# Convert the results to a DataFrame for better viewing
results_df = pd.DataFrame(results)

# Filter for statistically significant results at the 0.05 level
significant_results = results_df[results_df['p-value'] < 0.05]
# Out:
# <ipython-input-122-a5df3dd86adc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Infertility_Status'] = np.where(data['Infertility '].notna(), 1, 0)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# Skipping Benign Brain Tumor due to singular matrix issue.
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# Skipping Cystic Fibrosis due to singular matrix issue.
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# Skipping Epilepsy due to singular matrix issue.
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# Skipping COPD due to singular matrix issue.
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# Skipping Celiac Disease due to singular matrix issue.
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-122-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)

# %%
significant_results
# Out:
#              Comorbidity  Odds Ratio  95% CI Lower  95% CI Upper   p-value
# 15        Hyperlipidemia    0.219886      0.106199      0.455277  0.000045
# 43          Hypertension    0.211486      0.085696      0.521915  0.000750
# 74           Arthropathy    0.273679      0.110894      0.675417  0.004933
# 85  Congenital Anomalies    6.698079      2.107377     21.289149  0.001267

# %% [markdown]
# ## Psoriasis/Control - Infertility

# %%
data = df[selected_columns]
data
# Out:
#               date_of_birth  GroupName  age sex    Start_D  DiagYear  \
# 0       1906-05-15 00:00:00  Psoriasis   98   M 2005-08-03    2005.0
# 1       1906-06-15 00:00:00    Control   98   M 2005-08-03    2005.0
# 2       1907-06-15 00:00:00  Psoriasis   95   M 2003-10-12    2003.0
# 3       1907-05-14 00:00:00    Control   95   M 2003-10-12    2003.0
# 4       1909-01-01 00:00:00  Psoriasis  100   M 2009-06-30    2009.0
# ...                     ...        ...  ...  ..        ...       ...
# 280445  2016-06-03 00:00:00  Psoriasis    0   F 2017-11-14    2017.0
# 280446  2017-01-03 00:00:00    Control    0   F 2017-05-15    2017.0
# 280447  2017-01-08 00:00:00  Psoriasis    0   F 2017-05-15    2017.0
# 280448  2017-01-08 00:00:00    Control    0   F 2017-11-21    2017.0
# 280449  2017-01-14 00:00:00  Psoriasis    0   F 2017-11-21    2017.0
#
#        Infertility  Psoriasis Tuberculosis Tuberculosis s/p  ... OncBone  \
# 0               NaN       NaN          NaN              NaN  ...     NaN
# 1               NaN       NaN          NaN              NaN  ...     NaN
# 2               NaN       NaN          NaN              NaN  ...     NaN
# 3               NaN       NaN          NaN              NaN  ...     NaN
# 4               NaN       NaN          NaN              NaN  ...     NaN
# ...             ...       ...          ...              ...  ...     ...
# 280445          NaN       NaN          NaN              NaN  ...     NaN
# 280446          NaN       NaN          NaN              NaN  ...     NaN
# 280447          NaN       NaN          NaN              NaN  ...     NaN
# 280448          NaN       NaN          NaN              NaN  ...     NaN
# 280449          NaN       NaN          NaN              NaN  ...     NaN
#
#        OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 0              NaN          NaN        NaN                 NaN
# 1              NaN          NaN        NaN                 NaN
# 2              NaN          NaN        NaN                 NaN
# 3              NaN          NaN        NaN                 NaN
# 4              NaN          NaN        NaN                 NaN
# ...            ...          ...        ...                 ...
# 280445         NaN          NaN        NaN                 NaN
# 280446         NaN          NaN        NaN                 NaN
# 280447         NaN          NaN        NaN                 NaN
# 280448         NaN          NaN        NaN                 NaN
# 280449         NaN          NaN        NaN                 NaN
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 0                     NaN                 NaN                  NaN      NaN
# 1                     NaN                 NaN                  NaN      NaN
# 2                     NaN                 NaN                  NaN      NaN
# 3                     NaN                 NaN                  NaN      NaN
# 4                     NaN                 NaN                  NaN      NaN
# ...                   ...                 ...                  ...      ...
# 280445                NaN                 NaN                  NaN      NaN
# 280446                NaN                 NaN                  NaN      NaN
# 280447                NaN                 NaN                  NaN      NaN
# 280448                NaN                 NaN                  NaN      NaN
# 280449                NaN                 NaN                  NaN      NaN
#
#        OncUnKnow
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 280445       NaN
# 280446       NaN
# 280447       NaN
# 280448       NaN
# 280449       NaN
#
# [280450 rows x 133 columns]

# %%
data = data[data.sex == 'M']

# %%
# Converting date columns to datetime for comparison
data['Psoriasis'] = pd.to_datetime(data['Psoriasis'], errors='coerce')
data['Start_D'] = pd.to_datetime(data['Start_D'], errors='coerce')

# Set Psoriasis date based on group and availability
# If 'Psoriasis' is NaT and the group is "Psoriasis", use 'Start_D' as the proxy
data['Psoriasis'] = data.apply(
    lambda row: row['Start_D'] if pd.isna(row['Psoriasis']) and row['GroupName'] == 'Psoriasis' else row['Psoriasis'],
    axis=1
)
# Out:
# <ipython-input-132-2d7d9029a180>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Psoriasis'] = pd.to_datetime(data['Psoriasis'], errors='coerce')
# <ipython-input-132-2d7d9029a180>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Start_D'] = pd.to_datetime(data['Start_D'], errors='coerce')
# <ipython-input-132-2d7d9029a180>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Psoriasis'] = data.apply(

# %%
data
# Out:
#               date_of_birth  GroupName  age sex    Start_D  DiagYear  \
# 0       1906-05-15 00:00:00  Psoriasis   98   M 2005-08-03    2005.0
# 1       1906-06-15 00:00:00    Control   98   M 2005-08-03    2005.0
# 2       1907-06-15 00:00:00  Psoriasis   95   M 2003-10-12    2003.0
# 3       1907-05-14 00:00:00    Control   95   M 2003-10-12    2003.0
# 4       1909-01-01 00:00:00  Psoriasis  100   M 2009-06-30    2009.0
# ...                     ...        ...  ...  ..        ...       ...
# 138679  2016-01-30 00:00:00  Psoriasis    1   M 2017-03-30    2017.0
# 138680  2016-05-25 00:00:00    Control    0   M 2017-02-28    2017.0
# 138681  2016-06-15 00:00:00  Psoriasis    0   M 2017-02-28    2017.0
# 138682  2016-10-13 00:00:00  Psoriasis    0   M 2017-01-13    2017.0
# 138683  2016-06-18 00:00:00    Control    0   M 2017-01-13    2017.0
#
#        Infertility   Psoriasis Tuberculosis Tuberculosis s/p  ... OncBone  \
# 0               NaN 2005-08-03          NaN              NaN  ...     NaN
# 1               NaN        NaT          NaN              NaN  ...     NaN
# 2               NaN 2003-10-12          NaN              NaN  ...     NaN
# 3               NaN        NaT          NaN              NaN  ...     NaN
# 4               NaN 2009-06-30          NaN              NaN  ...     NaN
# ...             ...        ...          ...              ...  ...     ...
# 138679          NaN 2017-03-30          NaN              NaN  ...     NaN
# 138680          NaN        NaT          NaN              NaN  ...     NaN
# 138681          NaN 2017-02-28          NaN              NaN  ...     NaN
# 138682          NaN 2017-01-13          NaN              NaN  ...     NaN
# 138683          NaN        NaT          NaN              NaN  ...     NaN
#
#        OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 0              NaN          NaN        NaN                 NaN
# 1              NaN          NaN        NaN                 NaN
# 2              NaN          NaN        NaN                 NaN
# 3              NaN          NaN        NaN                 NaN
# 4              NaN          NaN        NaN                 NaN
# ...            ...          ...        ...                 ...
# 138679         NaN          NaN        NaN                 NaN
# 138680         NaN          NaN        NaN                 NaN
# 138681         NaN          NaN        NaN                 NaN
# 138682         NaN          NaN        NaN                 NaN
# 138683         NaN          NaN        NaN                 NaN
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 0                     NaN                 NaN                  NaN      NaN
# 1                     NaN                 NaN                  NaN      NaN
# 2                     NaN                 NaN                  NaN      NaN
# 3                     NaN                 NaN                  NaN      NaN
# 4                     NaN                 NaN                  NaN      NaN
# ...                   ...                 ...                  ...      ...
# 138679                NaN                 NaN                  NaN      NaN
# 138680                NaN                 NaN                  NaN      NaN
# 138681                NaN                 NaN                  NaN      NaN
# 138682                NaN                 NaN                  NaN      NaN
# 138683                NaN                 NaN                  NaN      NaN
#
#        OncUnKnow
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 138679       NaN
# 138680       NaN
# 138681       NaN
# 138682       NaN
# 138683       NaN
#
# [138684 rows x 133 columns]

# %%
# Identify comorbidity columns, assuming they start from "Tuberculosis" onwards
comorbidity_columns = data.columns[data.columns.get_loc("Tuberculosis"):]

# Iterate through comorbidity columns to adjust dates
for column in comorbidity_columns:
    data[column] = pd.to_datetime(data[column], errors='coerce')
    # Replace the date with NaN if it occurs after the relevant reference date
    data[column] = data.apply(
        lambda row: (
            row[column] if pd.isna(row[column]) or (
                (row['GroupName'] == 'Psoriasis' and row[column] <= row['Psoriasis']) or
                (row['GroupName'] != 'Psoriasis' and row[column] <= pd.to_datetime(row['Infertility ']))
            ) else pd.NaT
        ), 
        axis=1
    )
# Out:
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-133-525648255751>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-133-525648255751>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(

# %%
# Identify comorbidity columns, assuming they start from "Tuberculosis" onwards
comorbidity_columns = data.columns[data.columns.get_loc("Tuberculosis"):]

# Iterate through comorbidity columns to adjust dates
for column in comorbidity_columns:
    data[column] = pd.to_datetime(data[column], errors='coerce')
    # Replace the date with NaN if it occurs after the relevant reference date
    data[column] = data.apply(
        lambda row: (
            row[column] if pd.isna(row[column]) or (
                (row['GroupName'] == 'Psoriasis' and row[column] <= row['Psoriasis']) or
                (row['GroupName'] != 'Psoriasis' and row[column] <= row['Start_D'])
            ) else pd.NaT
        ), 
        axis=1
    )
# Out:
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-126-c325cc223aff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-126-c325cc223aff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(

# %%
data
# Out:
#               date_of_birth  GroupName  age sex    Start_D  DiagYear  \
# 0       1906-05-15 00:00:00  Psoriasis   98   M 2005-08-03    2005.0
# 1       1906-06-15 00:00:00    Control   98   M 2005-08-03    2005.0
# 2       1907-06-15 00:00:00  Psoriasis   95   M 2003-10-12    2003.0
# 3       1907-05-14 00:00:00    Control   95   M 2003-10-12    2003.0
# 4       1909-01-01 00:00:00  Psoriasis  100   M 2009-06-30    2009.0
# ...                     ...        ...  ...  ..        ...       ...
# 138679  2016-01-30 00:00:00  Psoriasis    1   M 2017-03-30    2017.0
# 138680  2016-05-25 00:00:00    Control    0   M 2017-02-28    2017.0
# 138681  2016-06-15 00:00:00  Psoriasis    0   M 2017-02-28    2017.0
# 138682  2016-10-13 00:00:00  Psoriasis    0   M 2017-01-13    2017.0
# 138683  2016-06-18 00:00:00    Control    0   M 2017-01-13    2017.0
#
#        Infertility   Psoriasis Tuberculosis Tuberculosis s/p  ... OncBone  \
# 0               NaN 2005-08-03          NaT              NaT  ...     NaT
# 1               NaN        NaT          NaT              NaT  ...     NaT
# 2               NaN 2003-10-12          NaT              NaT  ...     NaT
# 3               NaN        NaT          NaT              NaT  ...     NaT
# 4               NaN 2009-06-30          NaT              NaT  ...     NaT
# ...             ...        ...          ...              ...  ...     ...
# 138679          NaN 2017-03-30          NaT              NaT  ...     NaT
# 138680          NaN        NaT          NaT              NaT  ...     NaT
# 138681          NaN 2017-02-28          NaT              NaT  ...     NaT
# 138682          NaN 2017-01-13          NaT              NaT  ...     NaT
# 138683          NaN        NaT          NaT              NaT  ...     NaT
#
#        OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 0              NaT          NaT        NaT                 NaT
# 1              NaT          NaT        NaT                 NaT
# 2              NaT          NaT        NaT                 NaT
# 3              NaT          NaT        NaT                 NaT
# 4              NaT          NaT        NaT                 NaT
# ...            ...          ...        ...                 ...
# 138679         NaT          NaT        NaT                 NaT
# 138680         NaT          NaT        NaT                 NaT
# 138681         NaT          NaT        NaT                 NaT
# 138682         NaT          NaT        NaT                 NaT
# 138683         NaT          NaT        NaT                 NaT
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 0                     NaT                 NaT                  NaT      NaT
# 1                     NaT                 NaT                  NaT      NaT
# 2                     NaT                 NaT                  NaT      NaT
# 3                     NaT                 NaT                  NaT      NaT
# 4                     NaT                 NaT                  NaT      NaT
# ...                   ...                 ...                  ...      ...
# 138679                NaT                 NaT                  NaT      NaT
# 138680                NaT                 NaT                  NaT      NaT
# 138681                NaT                 NaT                  NaT      NaT
# 138682                NaT                 NaT                  NaT      NaT
# 138683                NaT                 NaT                  NaT      NaT
#
#        OncUnKnow
# 0            NaT
# 1            NaT
# 2            NaT
# 3            NaT
# 4            NaT
# ...          ...
# 138679       NaT
# 138680       NaT
# 138681       NaT
# 138682       NaT
# 138683       NaT
#
# [138684 rows x 133 columns]

# %%
# Convert Infertility column to datetime for comparison
data['Infertility '] = pd.to_datetime(data['Infertility '], errors='coerce')

# Filter psoriatic patients where infertility is diagnosed after the psoriasis date
data = data[
    (data['GroupName'] == 'Psoriasis') & 
    (data['Infertility '].notna()) & 
    (data['Infertility '] > data['Psoriasis'])
]

# Display the filtered data
data
# Out:
# <ipython-input-134-c12f9e7ba1fe>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Infertility '] = pd.to_datetime(data['Infertility '], errors='coerce')
#               date_of_birth  GroupName age sex    Start_D  DiagYear  \
# 1429    1923-06-05 00:00:00  Psoriasis  79   M 2003-11-30    2003.0
# 6355    1931-12-18 00:00:00  Psoriasis  73   M 2005-04-25    2005.0
# 24878   1946-08-10 00:00:00  Psoriasis  55   M 2002-11-27    2002.0
# 25415   1946-06-30 00:00:00  Psoriasis  58   M 2005-07-20    2005.0
# 28608   1947-04-01 00:00:00  Psoriasis  67   M 2014-08-17    2014.0
# ...                     ...        ...  ..  ..        ...       ...
# 116038  1988-12-08 00:00:00  Psoriasis  21   M 2010-04-15    2010.0
# 116565  1988-05-19 00:00:00  Psoriasis  25   M 2014-04-16    2014.0
# 118770  1989-10-06 00:00:00  Psoriasis  15   M 2005-04-05    2005.0
# 119648  1990-01-01 00:00:00  Psoriasis  17   M 2007-07-04    2007.0
# 122421  1992-08-05 00:00:00  Psoriasis  14   M 2007-02-17    2007.0
#
#        Infertility   Psoriasis Tuberculosis Tuberculosis s/p  ... OncBone  \
# 1429     2012-11-19 1998-08-01          NaT              NaT  ...     NaT
# 6355     2014-08-01 2005-04-25          NaT              NaT  ...     NaT
# 24878    2004-06-17 2003-05-01          NaT              NaT  ...     NaT
# 25415    2006-06-28 2001-05-07          NaT              NaT  ...     NaT
# 28608    2005-01-25 2000-07-01          NaT              NaT  ...     NaT
# ...             ...        ...          ...              ...  ...     ...
# 116038   2016-06-01 2010-04-15          NaT              NaT  ...     NaT
# 116565   2015-11-01 2014-04-16          NaT              NaT  ...     NaT
# 118770   2012-05-29 2005-04-05          NaT              NaT  ...     NaT
# 119648   2009-12-28 2007-07-04          NaT              NaT  ...     NaT
# 122421   2012-03-01 2007-02-17          NaT              NaT  ...     NaT
#
#        OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 1429           NaT          NaT        NaT                 NaT
# 6355           NaT          NaT        NaT                 NaT
# 24878          NaT          NaT        NaT                 NaT
# 25415          NaT          NaT        NaT                 NaT
# 28608          NaT          NaT        NaT                 NaT
# ...            ...          ...        ...                 ...
# 116038         NaT          NaT        NaT                 NaT
# 116565         NaT          NaT        NaT                 NaT
# 118770         NaT          NaT        NaT                 NaT
# 119648         NaT          NaT        NaT                 NaT
# 122421         NaT          NaT        NaT                 NaT
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 1429                  NaT                 NaT                  NaT      NaT
# 6355                  NaT                 NaT                  NaT      NaT
# 24878                 NaT                 NaT                  NaT      NaT
# 25415                 NaT                 NaT                  NaT      NaT
# 28608                 NaT                 NaT                  NaT      NaT
# ...                   ...                 ...                  ...      ...
# 116038                NaT                 NaT                  NaT      NaT
# 116565                NaT                 NaT                  NaT      NaT
# 118770                NaT                 NaT                  NaT      NaT
# 119648                NaT                 NaT                  NaT      NaT
# 122421                NaT                 NaT                  NaT      NaT
#
#        OncUnKnow
# 1429         NaT
# 6355         NaT
# 24878        NaT
# 25415        NaT
# 28608        NaT
# ...          ...
# 116038       NaT
# 116565       NaT
# 118770       NaT
# 119648       NaT
# 122421       NaT
#
# [86 rows x 133 columns]

# %%
# Convert Infertility column to datetime for comparison
data['Infertility '] = pd.to_datetime(data['Infertility '], errors='coerce')

# Filter psoriatic patients where infertility is diagnosed after the psoriasis date
psoriatic_with_infertility = data[
    (data['GroupName'] == 'Psoriasis') & 
    (data['Infertility '].notna()) & 
    (data['Infertility '] > data['Psoriasis'])
]

# Filter control patients where infertility is diagnosed after the start date
control_with_infertility = data[
    (data['GroupName'] != 'Psoriasis') & 
    (data['Infertility '].notna()) & 
    (data['Infertility '] > data['Start_D'])
]

# Combine both groups to create a dataset of all patients with infertility (psoriatic and control)
data_with_infertility = pd.concat([psoriatic_with_infertility, control_with_infertility])

# Display the filtered data
data_with_infertility
# Out:
# <ipython-input-127-be7ab5e5cdd2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Infertility '] = pd.to_datetime(data['Infertility '], errors='coerce')
#               date_of_birth  GroupName age sex    Start_D  DiagYear  \
# 1429    1923-06-05 00:00:00  Psoriasis  79   M 2003-11-30    2003.0
# 6355    1931-12-18 00:00:00  Psoriasis  73   M 2005-04-25    2005.0
# 24878   1946-08-10 00:00:00  Psoriasis  55   M 2002-11-27    2002.0
# 25415   1946-06-30 00:00:00  Psoriasis  58   M 2005-07-20    2005.0
# 28608   1947-04-01 00:00:00  Psoriasis  67   M 2014-08-17    2014.0
# ...                     ...        ...  ..  ..        ...       ...
# 115527  1987-12-05 00:00:00    Control  16   M 2004-12-21    2004.0
# 115551  1987-11-03 00:00:00    Control  27   M 2015-08-07    2015.0
# 116774  1988-01-24 00:00:00    Control  17   M 2005-03-23    2005.0
# 116798  1988-09-04 00:00:00    Control  25   M 2014-12-15    2014.0
# 124273  1993-01-19 00:00:00    Control  12   M 2005-04-19    2005.0
#
#        Infertility   Psoriasis Tuberculosis Tuberculosis s/p  ... OncBone  \
# 1429     2012-11-19 1998-08-01          NaT              NaT  ...     NaT
# 6355     2014-08-01 2005-04-25          NaT              NaT  ...     NaT
# 24878    2004-06-17 2003-05-01          NaT              NaT  ...     NaT
# 25415    2006-06-28 2001-05-07          NaT              NaT  ...     NaT
# 28608    2005-01-25 2000-07-01          NaT              NaT  ...     NaT
# ...             ...        ...          ...              ...  ...     ...
# 115527   2008-03-01        NaT          NaT              NaT  ...     NaT
# 115551   2016-09-26        NaT          NaT              NaT  ...     NaT
# 116774   2013-03-18        NaT          NaT              NaT  ...     NaT
# 116798   2017-11-01        NaT          NaT              NaT  ...     NaT
# 124273   2017-10-09        NaT          NaT              NaT  ...     NaT
#
#        OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 1429           NaT          NaT        NaT                 NaT
# 6355           NaT          NaT        NaT                 NaT
# 24878          NaT          NaT        NaT                 NaT
# 25415          NaT          NaT        NaT                 NaT
# 28608          NaT          NaT        NaT                 NaT
# ...            ...          ...        ...                 ...
# 115527         NaT          NaT        NaT                 NaT
# 115551         NaT          NaT        NaT                 NaT
# 116774         NaT          NaT        NaT                 NaT
# 116798         NaT          NaT        NaT                 NaT
# 124273         NaT          NaT        NaT                 NaT
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 1429                  NaT                 NaT                  NaT      NaT
# 6355                  NaT                 NaT                  NaT      NaT
# 24878                 NaT                 NaT                  NaT      NaT
# 25415                 NaT                 NaT                  NaT      NaT
# 28608                 NaT                 NaT                  NaT      NaT
# ...                   ...                 ...                  ...      ...
# 115527                NaT                 NaT                  NaT      NaT
# 115551                NaT                 NaT                  NaT      NaT
# 116774                NaT                 NaT                  NaT      NaT
# 116798                NaT                 NaT                  NaT      NaT
# 124273                NaT                 NaT                  NaT      NaT
#
#         OncUnKnow
# 1429          NaT
# 6355          NaT
# 24878         NaT
# 25415         NaT
# 28608         NaT
# ...           ...
# 115527        NaT
# 115551        NaT
# 116774        NaT
# 116798 2010-09-07
# 124273        NaT
#
# [149 rows x 133 columns]

# %%
# Assuming `data_with_infertility` contains both psoriatic and control patients with infertility
# Create a binary variable for psoriasis status: 1 for Psoriatic, 0 for Control
data_with_infertility['Psoriasis_Status'] = np.where(data_with_infertility['GroupName'] == 'Psoriasis', 1, 0)

# List of comorbidity columns to include in the logistic regression
comorbidity_columns = data_with_infertility.columns[data_with_infertility.columns.get_loc("Tuberculosis"):]

# To store the results of each regression
results = []

# Loop through each comorbidity to perform logistic regression
for comorbidity in comorbidity_columns:
    # Create binary variable for presence of comorbidity
    data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)

    # Check for variability: skip if there is no or minimal variation
    count = data_with_infertility[comorbidity + '_status'].sum()
    if count == 0 or count == len(data_with_infertility) or count < 5:  # Skipping if too few positive cases
        continue

    # Define the independent variable (comorbidity) and the dependent variable (Psoriasis_Status)
    X = data_with_infertility[[comorbidity + '_status']]
    y = data_with_infertility['Psoriasis_Status']

    # Add an intercept to the independent variable
    X = sm.add_constant(X)

    try:
        # Fit the logistic regression model
        model = sm.Logit(y, X)
        result = model.fit(disp=False)

        # Calculate Odds Ratio for the comorbidity
        odds_ratio = np.exp(result.params[comorbidity + '_status'])
        ci = result.conf_int().loc[comorbidity + '_status']
        ci_odds_ratio = np.exp(ci)

        # Extract p-value for the comorbidity
        p_value = result.pvalues[comorbidity + '_status']

        # Append the results for the comorbidity
        results.append({
            'Comorbidity': comorbidity,
            'Odds Ratio': odds_ratio,
            '95% CI Lower': ci_odds_ratio[0],
            '95% CI Upper': ci_odds_ratio[1],
            'p-value': p_value
        })

    except np.linalg.LinAlgError:
        # Handle any singular matrix errors due to collinearity or insufficient data
        print(f"Skipping {comorbidity} due to singular matrix issue.")
        continue

# Convert the results to a DataFrame for better viewing
results_df = pd.DataFrame(results)

# Filter for statistically significant results at the 0.001 level
significant_results = results_df[results_df['p-value'] < 0.001]
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)
# <ipython-input-137-727b557476ca>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_with_infertility[comorbidity + '_status'] = data_with_infertility[comorbidity].notna().astype(int)

# %%
significant_results
# Out:
# Empty DataFrame
# Columns: [Comorbidity, Odds Ratio, 95% CI Lower, 95% CI Upper, p-value]
# Index: []

# %%
data = df[selected_columns]
data
# Out:
#               date_of_birth  GroupName  age sex    Start_D  DiagYear  \
# 0       1906-05-15 00:00:00  Psoriasis   98   M 2005-08-03    2005.0
# 1       1906-06-15 00:00:00    Control   98   M 2005-08-03    2005.0
# 2       1907-06-15 00:00:00  Psoriasis   95   M 2003-10-12    2003.0
# 3       1907-05-14 00:00:00    Control   95   M 2003-10-12    2003.0
# 4       1909-01-01 00:00:00  Psoriasis  100   M 2009-06-30    2009.0
# ...                     ...        ...  ...  ..        ...       ...
# 280445  2016-06-03 00:00:00  Psoriasis    0   F 2017-11-14    2017.0
# 280446  2017-01-03 00:00:00    Control    0   F 2017-05-15    2017.0
# 280447  2017-01-08 00:00:00  Psoriasis    0   F 2017-05-15    2017.0
# 280448  2017-01-08 00:00:00    Control    0   F 2017-11-21    2017.0
# 280449  2017-01-14 00:00:00  Psoriasis    0   F 2017-11-21    2017.0
#
#        Infertility  Psoriasis Tuberculosis Tuberculosis s/p  ... OncBone  \
# 0               NaN       NaN          NaN              NaN  ...     NaN
# 1               NaN       NaN          NaN              NaN  ...     NaN
# 2               NaN       NaN          NaN              NaN  ...     NaN
# 3               NaN       NaN          NaN              NaN  ...     NaN
# 4               NaN       NaN          NaN              NaN  ...     NaN
# ...             ...       ...          ...              ...  ...     ...
# 280445          NaN       NaN          NaN              NaN  ...     NaN
# 280446          NaN       NaN          NaN              NaN  ...     NaN
# 280447          NaN       NaN          NaN              NaN  ...     NaN
# 280448          NaN       NaN          NaN              NaN  ...     NaN
# 280449          NaN       NaN          NaN              NaN  ...     NaN
#
#        OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 0              NaN          NaN        NaN                 NaN
# 1              NaN          NaN        NaN                 NaN
# 2              NaN          NaN        NaN                 NaN
# 3              NaN          NaN        NaN                 NaN
# 4              NaN          NaN        NaN                 NaN
# ...            ...          ...        ...                 ...
# 280445         NaN          NaN        NaN                 NaN
# 280446         NaN          NaN        NaN                 NaN
# 280447         NaN          NaN        NaN                 NaN
# 280448         NaN          NaN        NaN                 NaN
# 280449         NaN          NaN        NaN                 NaN
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 0                     NaN                 NaN                  NaN      NaN
# 1                     NaN                 NaN                  NaN      NaN
# 2                     NaN                 NaN                  NaN      NaN
# 3                     NaN                 NaN                  NaN      NaN
# 4                     NaN                 NaN                  NaN      NaN
# ...                   ...                 ...                  ...      ...
# 280445                NaN                 NaN                  NaN      NaN
# 280446                NaN                 NaN                  NaN      NaN
# 280447                NaN                 NaN                  NaN      NaN
# 280448                NaN                 NaN                  NaN      NaN
# 280449                NaN                 NaN                  NaN      NaN
#
#        OncUnKnow
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 280445       NaN
# 280446       NaN
# 280447       NaN
# 280448       NaN
# 280449       NaN
#
# [280450 rows x 133 columns]

# %%
data[(data.GroupName == 'Control') & (data['Infertility '].notna())]
# Out:
#               date_of_birth GroupName age sex    Start_D  DiagYear  \
# 1592    1923-04-01 00:00:00   Control  82   M 2006-03-01    2006.0
# 1809    1924-06-20 00:00:00   Control  85   M 2010-10-03    2010.0
# 2792    1926-01-01 00:00:00   Control  82   M 2008-09-03    2008.0
# 3451    1927-04-10 00:00:00   Control  77   M 2005-09-12    2005.0
# 4152    1928-01-01 00:00:00   Control  79   M 2007-07-01    2007.0
# ...                     ...       ...  ..  ..        ...       ...
# 266035  1995-08-05 00:00:00   Control  17   F 2013-02-06    2013.0
# 267018  1996-09-10 00:00:00   Control  14   F 2011-09-22    2011.0
# 268094  1997-06-18 00:00:00   Control   9   F 2007-02-15    2007.0
# 268723  1998-01-14 00:00:00   Control  19   F 2017-02-14    2017.0
# 271650  2000-08-04 00:00:00   Control   9   F 2010-01-06    2010.0
#
#                Infertility  Psoriasis Tuberculosis     Tuberculosis s/p  ...  \
# 1592    2004-09-17 00:00:00       NaN          NaN  1999-12-19 00:00:00  ...
# 1809    2002-01-28 00:00:00       NaN          NaN                  NaN  ...
# 2792    2004-03-24 00:00:00       NaN          NaN                  NaN  ...
# 3451    2003-02-02 00:00:00       NaN          NaN                  NaN  ...
# 4152    2001-04-24 00:00:00       NaN          NaN                  NaN  ...
# ...                     ...       ...          ...                  ...  ...
# 266035  2016-03-08 00:00:00       NaN          NaN                  NaN  ...
# 267018  2016-09-06 00:00:00       NaN          NaN                  NaN  ...
# 268094  2017-11-16 00:00:00       NaN          NaN                  NaN  ...
# 268723  2016-12-04 00:00:00       NaN          NaN                  NaN  ...
# 271650  2016-07-15 00:00:00       NaN          NaN                  NaN  ...
#
#        OncBone OncSaracoma OncGenitalia Oncmyeloma  OncPolycythemiaVera  \
# 1592       NaN         NaN          NaN        NaN  2004-09-01 00:00:00
# 1809       NaN         NaN          NaN        NaN                  NaN
# 2792       NaN         NaN          NaN        NaN                  NaN
# 3451       NaN         NaN          NaN        NaN  2010-04-01 00:00:00
# 4152       NaN         NaN          NaN        NaN                  NaN
# ...        ...         ...          ...        ...                  ...
# 266035     NaN         NaN          NaN        NaN                  NaN
# 267018     NaN         NaN          NaN        NaN                  NaN
# 268094     NaN         NaN          NaN        NaN                  NaN
# 268723     NaN         NaN          NaN        NaN                  NaN
# 271650     NaN         NaN          NaN        NaN                  NaN
#
#          OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 1592                    NaN                 NaN                  NaN      NaN
# 1809                    NaN                 NaN                  NaN      NaN
# 2792                    NaN                 NaN                  NaN      NaN
# 3451                    NaN                 NaN                  NaN      NaN
# 4152    2002-01-24 00:00:00                 NaN                  NaN      NaN
# ...                     ...                 ...                  ...      ...
# 266035                  NaN                 NaN                  NaN      NaN
# 267018                  NaN                 NaN                  NaN      NaN
# 268094                  NaN                 NaN                  NaN      NaN
# 268723                  NaN                 NaN                  NaN      NaN
# 271650                  NaN                 NaN                  NaN      NaN
#
#        OncUnKnow
# 1592         NaN
# 1809         NaN
# 2792         NaN
# 3451         NaN
# 4152         NaN
# ...          ...
# 266035       NaN
# 267018       NaN
# 268094       NaN
# 268723       NaN
# 271650       NaN
#
# [3548 rows x 133 columns]

# %%
data[(pd.to_datetime(data['Infertility ']) > pd.to_datetime(data['Start_D'])) & (data.sex == 'M')]
# Out:
#               date_of_birth  GroupName age sex    Start_D  DiagYear  \
# 1429    1923-06-05 00:00:00  Psoriasis  79   M 2003-11-30    2003.0
# 6355    1931-12-18 00:00:00  Psoriasis  73   M 2005-04-25    2005.0
# 11818   1936-03-04 00:00:00    Control  66   M 2003-01-02    2003.0
# 15690   1939-10-04 00:00:00    Control  64   M 2004-04-01    2004.0
# 22681   1944-04-01 00:00:00    Control  60   M 2004-06-21    2004.0
# ...                     ...        ...  ..  ..        ...       ...
# 116798  1988-09-04 00:00:00    Control  25   M 2014-12-15    2014.0
# 118770  1989-10-06 00:00:00  Psoriasis  15   M 2005-04-05    2005.0
# 119648  1990-01-01 00:00:00  Psoriasis  17   M 2007-07-04    2007.0
# 122421  1992-08-05 00:00:00  Psoriasis  14   M 2007-02-17    2007.0
# 124273  1993-01-19 00:00:00    Control  12   M 2005-04-19    2005.0
#
#                Infertility             Psoriasis Tuberculosis  \
# 1429    2012-11-19 00:00:00  1998-08-01 00:00:00          NaN
# 6355    2014-08-01 00:00:00                  NaN          NaN
# 11818   2004-02-15 00:00:00                  NaN          NaN
# 15690   2004-08-04 00:00:00                  NaN          NaN
# 22681   2004-12-13 00:00:00                  NaN          NaN
# ...                     ...                  ...          ...
# 116798  2017-11-01 00:00:00                  NaN          NaN
# 118770  2012-05-29 00:00:00                  NaN          NaN
# 119648  2009-12-28 00:00:00                  NaN          NaN
# 122421  2012-03-01 00:00:00                  NaN          NaN
# 124273  2017-10-09 00:00:00                  NaN          NaN
#
#        Tuberculosis s/p  ... OncBone          OncSaracoma OncGenitalia  \
# 1429                NaN  ...     NaN  2007-07-01 00:00:00          NaN
# 6355                NaN  ...     NaN                  NaN          NaN
# 11818               NaN  ...     NaN                  NaN          NaN
# 15690               NaN  ...     NaN                  NaN          NaN
# 22681               NaN  ...     NaN                  NaN          NaN
# ...                 ...  ...     ...                  ...          ...
# 116798              NaN  ...     NaN                  NaN          NaN
# 118770              NaN  ...     NaN                  NaN          NaN
# 119648              NaN  ...     NaN                  NaN          NaN
# 122421              NaN  ...     NaN                  NaN          NaN
# 124273              NaN  ...     NaN                  NaN          NaN
#
#        Oncmyeloma OncPolycythemiaVera OncMyelodysplastic OncLympholiferative  \
# 1429          NaN                 NaN                NaN                 NaN
# 6355          NaN                 NaN                NaN                 NaN
# 11818         NaN                 NaN                NaN                 NaN
# 15690         NaN                 NaN                NaN                 NaN
# 22681         NaN                 NaN                NaN                 NaN
# ...           ...                 ...                ...                 ...
# 116798        NaN                 NaN                NaN                 NaN
# 118770        NaN                 NaN                NaN                 NaN
# 119648        NaN                 NaN                NaN                 NaN
# 122421        NaN                 NaN                NaN                 NaN
# 124273        NaN                 NaN                NaN                 NaN
#
#        OncNeurofibromatosis             OncOther            OncUnKnow
# 1429                    NaN  2012-08-19 00:00:00                  NaN
# 6355                    NaN                  NaN                  NaN
# 11818                   NaN                  NaN                  NaN
# 15690                   NaN                  NaN                  NaN
# 22681                   NaN                  NaN                  NaN
# ...                     ...                  ...                  ...
# 116798                  NaN                  NaN  2010-09-07 00:00:00
# 118770                  NaN                  NaN                  NaN
# 119648                  NaN                  NaN                  NaN
# 122421                  NaN                  NaN                  NaN
# 124273                  NaN                  NaN                  NaN
#
# [131 rows x 133 columns]

# %% [markdown]
# ## Psoriasis - Infertility/NonInfertility

# %%
#Taking out psoriatic patients that do not have a diagnosis date
data = df[selected_columns]
data
# Out:
#               date_of_birth  GroupName  age sex    Start_D  DiagYear  \
# 0       1906-05-15 00:00:00  Psoriasis   98   M 2005-08-03    2005.0
# 1       1906-06-15 00:00:00    Control   98   M 2005-08-03    2005.0
# 2       1907-06-15 00:00:00  Psoriasis   95   M 2003-10-12    2003.0
# 3       1907-05-14 00:00:00    Control   95   M 2003-10-12    2003.0
# 4       1909-01-01 00:00:00  Psoriasis  100   M 2009-06-30    2009.0
# ...                     ...        ...  ...  ..        ...       ...
# 280445  2016-06-03 00:00:00  Psoriasis    0   F 2017-11-14    2017.0
# 280446  2017-01-03 00:00:00    Control    0   F 2017-05-15    2017.0
# 280447  2017-01-08 00:00:00  Psoriasis    0   F 2017-05-15    2017.0
# 280448  2017-01-08 00:00:00    Control    0   F 2017-11-21    2017.0
# 280449  2017-01-14 00:00:00  Psoriasis    0   F 2017-11-21    2017.0
#
#        Infertility  Psoriasis Tuberculosis Tuberculosis s/p  ... OncBone  \
# 0               NaN       NaN          NaN              NaN  ...     NaN
# 1               NaN       NaN          NaN              NaN  ...     NaN
# 2               NaN       NaN          NaN              NaN  ...     NaN
# 3               NaN       NaN          NaN              NaN  ...     NaN
# 4               NaN       NaN          NaN              NaN  ...     NaN
# ...             ...       ...          ...              ...  ...     ...
# 280445          NaN       NaN          NaN              NaN  ...     NaN
# 280446          NaN       NaN          NaN              NaN  ...     NaN
# 280447          NaN       NaN          NaN              NaN  ...     NaN
# 280448          NaN       NaN          NaN              NaN  ...     NaN
# 280449          NaN       NaN          NaN              NaN  ...     NaN
#
#        OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 0              NaN          NaN        NaN                 NaN
# 1              NaN          NaN        NaN                 NaN
# 2              NaN          NaN        NaN                 NaN
# 3              NaN          NaN        NaN                 NaN
# 4              NaN          NaN        NaN                 NaN
# ...            ...          ...        ...                 ...
# 280445         NaN          NaN        NaN                 NaN
# 280446         NaN          NaN        NaN                 NaN
# 280447         NaN          NaN        NaN                 NaN
# 280448         NaN          NaN        NaN                 NaN
# 280449         NaN          NaN        NaN                 NaN
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 0                     NaN                 NaN                  NaN      NaN
# 1                     NaN                 NaN                  NaN      NaN
# 2                     NaN                 NaN                  NaN      NaN
# 3                     NaN                 NaN                  NaN      NaN
# 4                     NaN                 NaN                  NaN      NaN
# ...                   ...                 ...                  ...      ...
# 280445                NaN                 NaN                  NaN      NaN
# 280446                NaN                 NaN                  NaN      NaN
# 280447                NaN                 NaN                  NaN      NaN
# 280448                NaN                 NaN                  NaN      NaN
# 280449                NaN                 NaN                  NaN      NaN
#
#        OncUnKnow
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 280445       NaN
# 280446       NaN
# 280447       NaN
# 280448       NaN
# 280449       NaN
#
# [280450 rows x 133 columns]

# %%
data = data[data.GroupName == 'Psoriasis']
data = data[data.sex == 'M']
data = data[data.Psoriasis.notna()]
data
# Out:
#               date_of_birth  GroupName age sex    Start_D  DiagYear  \
# 7       1909-05-01 00:00:00  Psoriasis  93   M 2003-04-24    2003.0
# 8       1909-06-09 00:00:00  Psoriasis  94   M 2004-09-20    2004.0
# 25      1911-07-27 00:00:00  Psoriasis  95   M 2007-03-04    2007.0
# 31      1911-05-02 00:00:00  Psoriasis  91   M 2003-04-06    2003.0
# 36      1911-01-01 00:00:00  Psoriasis  94   M 2005-03-13    2005.0
# ...                     ...        ...  ..  ..        ...       ...
# 138362  2013-08-20 00:00:00  Psoriasis   1   M 2015-12-18    2015.0
# 138417  2014-10-03 00:00:00  Psoriasis   0   M 2015-01-25    2015.0
# 138437  2014-07-25 00:00:00  Psoriasis   0   M 2015-12-13    2015.0
# 138562  2015-01-23 00:00:00  Psoriasis   2   M 2017-08-31    2017.0
# 138650  2016-05-13 00:00:00  Psoriasis   0   M 2017-03-12    2017.0
#
#        Infertility             Psoriasis Tuberculosis Tuberculosis s/p  ...  \
# 7               NaN  1999-11-16 00:00:00          NaN              NaN  ...
# 8               NaN  2004-02-23 00:00:00          NaN              NaN  ...
# 25              NaN  2007-04-08 00:00:00          NaN              NaN  ...
# 31              NaN  2000-11-17 00:00:00          NaN              NaN  ...
# 36              NaN  2006-12-06 00:00:00          NaN              NaN  ...
# ...             ...                  ...          ...              ...  ...
# 138362          NaN  2015-12-18 00:00:00          NaN              NaN  ...
# 138417          NaN  2015-01-25 00:00:00          NaN              NaN  ...
# 138437          NaN  2015-11-03 00:00:00          NaN              NaN  ...
# 138562          NaN  2018-02-08 00:00:00          NaN              NaN  ...
# 138650          NaN  2017-03-12 00:00:00          NaN              NaN  ...
#
#        OncBone OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 7          NaN         NaN          NaN        NaN                 NaN
# 8          NaN         NaN          NaN        NaN                 NaN
# 25         NaN         NaN          NaN        NaN                 NaN
# 31         NaN         NaN          NaN        NaN                 NaN
# 36         NaN         NaN          NaN        NaN                 NaN
# ...        ...         ...          ...        ...                 ...
# 138362     NaN         NaN          NaN        NaN                 NaN
# 138417     NaN         NaN          NaN        NaN                 NaN
# 138437     NaN         NaN          NaN        NaN                 NaN
# 138562     NaN         NaN          NaN        NaN                 NaN
# 138650     NaN         NaN          NaN        NaN                 NaN
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 7                     NaN                 NaN                  NaN      NaN
# 8                     NaN                 NaN                  NaN      NaN
# 25                    NaN                 NaN                  NaN      NaN
# 31                    NaN                 NaN                  NaN      NaN
# 36                    NaN                 NaN                  NaN      NaN
# ...                   ...                 ...                  ...      ...
# 138362                NaN                 NaN                  NaN      NaN
# 138417                NaN                 NaN                  NaN      NaN
# 138437                NaN                 NaN                  NaN      NaN
# 138562                NaN                 NaN                  NaN      NaN
# 138650                NaN                 NaN                  NaN      NaN
#
#        OncUnKnow
# 7            NaN
# 8            NaN
# 25           NaN
# 31           NaN
# 36           NaN
# ...          ...
# 138362       NaN
# 138417       NaN
# 138437       NaN
# 138562       NaN
# 138650       NaN
#
# [14528 rows x 133 columns]

# %%
# Converting date columns to datetime for comparison
data['Psoriasis'] = pd.to_datetime(data['Psoriasis'], errors='coerce')

# Identify comorbidity columns, assuming they start from "Tuberculosis" onwards
comorbidity_columns = data.columns[data.columns.get_loc("Tuberculosis"):]

# Iterate through comorbidity columns to adjust dates
for column in comorbidity_columns:
    data[column] = pd.to_datetime(data[column], errors='coerce')
    # Replace the date with NaN if it occurs after the relevant reference date
    data[column] = data.apply(
        lambda row: (
            row[column] if pd.isna(row[column]) or (
                (row['GroupName'] == 'Psoriasis' and row[column] <= row['Psoriasis'])
            ) else pd.NaT
        ), 
        axis=1
    )

# %%
# Convert Infertility column to datetime for comparison
data['Infertility '] = pd.to_datetime(data['Infertility '], errors='coerce')

# Filter patients who have infertility diagnosed after psoriasis or have NaN under infertility
data = data[
    (data['Infertility '].isna()) |  # Keep patients with no infertility diagnosis (control group)
    (data['Infertility '] > data['Psoriasis'])  # Keep patients with infertility diagnosed after psoriasis
]

# %%
# Create binary variable for presence of infertility (Infertility_Status)
data['Infertility_Status'] = np.where(data['Infertility '].notna(), 1, 0)

# List of comorbidity columns to include in the logistic regression
comorbidity_columns = data.columns[data.columns.get_loc("Tuberculosis"):]

# To store the results of each regression
results = []

# Loop through each comorbidity to perform logistic regression
for comorbidity in comorbidity_columns:
    # Create binary variable for presence of comorbidity
    data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)

    # Check for variability: skip if there is no or minimal variation
    count = data[comorbidity + '_status'].sum()
    if count == 0 or count == len(data) or count < 5:  # Skipping if too few positive cases
        continue

    # Define the independent variable (comorbidity) and the dependent variable (Infertility_Status)
    X = data[[comorbidity + '_status']]
    y = data['Infertility_Status']

    # Add an intercept to the independent variable
    X = sm.add_constant(X)

    try:
        # Fit the logistic regression model
        model = sm.Logit(y, X)
        result = model.fit(disp=False)

        # Calculate Odds Ratio for the comorbidity
        odds_ratio = np.exp(result.params[comorbidity + '_status'])
        ci = result.conf_int().loc[comorbidity + '_status']
        ci_odds_ratio = np.exp(ci)

        # Extract p-value for the comorbidity
        p_value = result.pvalues[comorbidity + '_status']

        # Append the results for the comorbidity
        results.append({
            'Comorbidity': comorbidity,
            'Odds Ratio': odds_ratio,
            '95% CI Lower': ci_odds_ratio[0],
            '95% CI Upper': ci_odds_ratio[1],
            'p-value': p_value
        })

    except np.linalg.LinAlgError:
        # Handle any singular matrix errors due to collinearity or insufficient data
        print(f"Skipping {comorbidity} due to singular matrix issue.")
        continue

# Convert the results to a DataFrame for better viewing
results_df = pd.DataFrame(results)

# Filter for statistically significant results at the 0.05 level
significant_results = results_df[results_df['p-value'] < 0.05]
# Out:
# <ipython-input-143-a5df3dd86adc>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['Infertility_Status'] = np.where(data['Infertility '].notna(), 1, 0)
# <ipython-input-143-a5df3dd86adc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Infertility_Status'] = np.where(data['Infertility '].notna(), 1, 0)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# Skipping Hyperthyroidism due to singular matrix issue.
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# Skipping Psychoses due to singular matrix issue.
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Skipping Blindness due to singular matrix issue.
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# ...
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# Skipping Oncmyeloma due to singular matrix issue.
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-143-a5df3dd86adc>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-143-a5df3dd86adc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)

# %%
significant_results
# Out:
#            Comorbidity  Odds Ratio  95% CI Lower  95% CI Upper        p-value
# 13      Hyperlipidemia    0.365855      0.143236      0.934474   3.558725e-02
# 14  Hyperprolactinemia   33.592075      4.234190    266.503770   8.819210e-04
# 44                 PVD  410.191507    281.441971    597.839303  4.042972e-215
# 68         Arthropathy    0.213703      0.051526      0.886325   3.348417e-02

# %%
data[data.age == 1]
# Out:
#               date_of_birth  GroupName age sex    Start_D  DiagYear  \
# 131646  2001-03-11 00:00:00  Psoriasis   1   M 2003-12-31    2003.0
# 133611  2003-06-15 00:00:00  Psoriasis   1   M 2005-07-11    2005.0
# 133781  2004-02-23 00:00:00  Psoriasis   1   M 2006-02-01    2006.0
# 134327  2005-03-20 00:00:00  Psoriasis   1   M 2007-07-16    2007.0
# 136415  2008-07-19 00:00:00  Psoriasis   1   M 2010-12-10    2010.0
# 136804  2009-04-27 00:00:00  Psoriasis   1   M 2011-01-26    2011.0
# 137060  2009-03-09 00:00:00  Psoriasis   1   M 2011-09-26    2011.0
# 138362  2013-08-20 00:00:00  Psoriasis   1   M 2015-12-18    2015.0
#
#        Infertility   Psoriasis Tuberculosis Tuberculosis s/p  ...  \
# 131646          NaT 2008-01-16          NaT              NaT  ...
# 133611          NaT 2008-01-16          NaT              NaT  ...
# 133781          NaT 2006-02-02          NaT              NaT  ...
# 134327          NaT 2012-03-01          NaT              NaT  ...
# 136415          NaT 2014-04-01          NaT              NaT  ...
# 136804          NaT 2012-01-01          NaT              NaT  ...
# 137060          NaT 2011-11-01          NaT              NaT  ...
# 138362          NaT 2015-12-18          NaT              NaT  ...
#
#        OncSaracoma_status OncGenitalia_status Oncmyeloma_status  \
# 131646                  0                   0                 0
# 133611                  0                   0                 0
# 133781                  0                   0                 0
# 134327                  0                   0                 0
# 136415                  0                   0                 0
# 136804                  0                   0                 0
# 137060                  0                   0                 0
# 138362                  0                   0                 0
#
#        OncPolycythemiaVera_status OncMyelodysplastic_status  \
# 131646                          0                         0
# 133611                          0                         0
# 133781                          0                         0
# 134327                          0                         0
# 136415                          0                         0
# 136804                          0                         0
# 137060                          0                         0
# 138362                          0                         0
#
#        OncLympholiferative_status OncNeurofibromatosis_status OncOther_status  \
# 131646                          0                           0               0
# 133611                          0                           0               0
# 133781                          0                           0               0
# 134327                          0                           0               0
# 136415                          0                           0               0
# 136804                          0                           0               0
# 137060                          0                           0               0
# 138362                          0                           0               0
#
#        OncUnKnow_status Infertility_Status_status
# 131646                0                         1
# 133611                0                         1
# 133781                0                         1
# 134327                0                         1
# 136415                0                         1
# 136804                0                         1
# 137060                0                         1
# 138362                0                         1
#
# [8 rows x 260 columns]

# %% [markdown]
# ## Pazienti Ipertrofia prostatica + Cancro Prostata in gruppo Psoriasi

# %%
data = df[selected_columns]
data
# Out:
#               date_of_birth  GroupName  age sex    Start_D  DiagYear  \
# 0       1906-05-15 00:00:00  Psoriasis   98   M 2005-08-03    2005.0
# 1       1906-06-15 00:00:00    Control   98   M 2005-08-03    2005.0
# 2       1907-06-15 00:00:00  Psoriasis   95   M 2003-10-12    2003.0
# 3       1907-05-14 00:00:00    Control   95   M 2003-10-12    2003.0
# 4       1909-01-01 00:00:00  Psoriasis  100   M 2009-06-30    2009.0
# ...                     ...        ...  ...  ..        ...       ...
# 280445  2016-06-03 00:00:00  Psoriasis    0   F 2017-11-14    2017.0
# 280446  2017-01-03 00:00:00    Control    0   F 2017-05-15    2017.0
# 280447  2017-01-08 00:00:00  Psoriasis    0   F 2017-05-15    2017.0
# 280448  2017-01-08 00:00:00    Control    0   F 2017-11-21    2017.0
# 280449  2017-01-14 00:00:00  Psoriasis    0   F 2017-11-21    2017.0
#
#        Infertility  Psoriasis Tuberculosis Tuberculosis s/p  ... OncBone  \
# 0               NaN       NaN          NaN              NaN  ...     NaN
# 1               NaN       NaN          NaN              NaN  ...     NaN
# 2               NaN       NaN          NaN              NaN  ...     NaN
# 3               NaN       NaN          NaN              NaN  ...     NaN
# 4               NaN       NaN          NaN              NaN  ...     NaN
# ...             ...       ...          ...              ...  ...     ...
# 280445          NaN       NaN          NaN              NaN  ...     NaN
# 280446          NaN       NaN          NaN              NaN  ...     NaN
# 280447          NaN       NaN          NaN              NaN  ...     NaN
# 280448          NaN       NaN          NaN              NaN  ...     NaN
# 280449          NaN       NaN          NaN              NaN  ...     NaN
#
#        OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 0              NaN          NaN        NaN                 NaN
# 1              NaN          NaN        NaN                 NaN
# 2              NaN          NaN        NaN                 NaN
# 3              NaN          NaN        NaN                 NaN
# 4              NaN          NaN        NaN                 NaN
# ...            ...          ...        ...                 ...
# 280445         NaN          NaN        NaN                 NaN
# 280446         NaN          NaN        NaN                 NaN
# 280447         NaN          NaN        NaN                 NaN
# 280448         NaN          NaN        NaN                 NaN
# 280449         NaN          NaN        NaN                 NaN
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 0                     NaN                 NaN                  NaN      NaN
# 1                     NaN                 NaN                  NaN      NaN
# 2                     NaN                 NaN                  NaN      NaN
# 3                     NaN                 NaN                  NaN      NaN
# 4                     NaN                 NaN                  NaN      NaN
# ...                   ...                 ...                  ...      ...
# 280445                NaN                 NaN                  NaN      NaN
# 280446                NaN                 NaN                  NaN      NaN
# 280447                NaN                 NaN                  NaN      NaN
# 280448                NaN                 NaN                  NaN      NaN
# 280449                NaN                 NaN                  NaN      NaN
#
#        OncUnKnow
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 280445       NaN
# 280446       NaN
# 280447       NaN
# 280448       NaN
# 280449       NaN
#
# [280450 rows x 133 columns]

# %%
data = data[data.sex == 'M']

# %%
data
# Out:
#               date_of_birth  GroupName  age sex    Start_D  DiagYear  \
# 0       1906-05-15 00:00:00  Psoriasis   98   M 2005-08-03    2005.0
# 1       1906-06-15 00:00:00    Control   98   M 2005-08-03    2005.0
# 2       1907-06-15 00:00:00  Psoriasis   95   M 2003-10-12    2003.0
# 3       1907-05-14 00:00:00    Control   95   M 2003-10-12    2003.0
# 4       1909-01-01 00:00:00  Psoriasis  100   M 2009-06-30    2009.0
# ...                     ...        ...  ...  ..        ...       ...
# 138679  2016-01-30 00:00:00  Psoriasis    1   M 2017-03-30    2017.0
# 138680  2016-05-25 00:00:00    Control    0   M 2017-02-28    2017.0
# 138681  2016-06-15 00:00:00  Psoriasis    0   M 2017-02-28    2017.0
# 138682  2016-10-13 00:00:00  Psoriasis    0   M 2017-01-13    2017.0
# 138683  2016-06-18 00:00:00    Control    0   M 2017-01-13    2017.0
#
#        Infertility  Psoriasis Tuberculosis Tuberculosis s/p  ... OncBone  \
# 0               NaN       NaN          NaN              NaN  ...     NaN
# 1               NaN       NaN          NaN              NaN  ...     NaN
# 2               NaN       NaN          NaN              NaN  ...     NaN
# 3               NaN       NaN          NaN              NaN  ...     NaN
# 4               NaN       NaN          NaN              NaN  ...     NaN
# ...             ...       ...          ...              ...  ...     ...
# 138679          NaN       NaN          NaN              NaN  ...     NaN
# 138680          NaN       NaN          NaN              NaN  ...     NaN
# 138681          NaN       NaN          NaN              NaN  ...     NaN
# 138682          NaN       NaN          NaN              NaN  ...     NaN
# 138683          NaN       NaN          NaN              NaN  ...     NaN
#
#        OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 0              NaN          NaN        NaN                 NaN
# 1              NaN          NaN        NaN                 NaN
# 2              NaN          NaN        NaN                 NaN
# 3              NaN          NaN        NaN                 NaN
# 4              NaN          NaN        NaN                 NaN
# ...            ...          ...        ...                 ...
# 138679         NaN          NaN        NaN                 NaN
# 138680         NaN          NaN        NaN                 NaN
# 138681         NaN          NaN        NaN                 NaN
# 138682         NaN          NaN        NaN                 NaN
# 138683         NaN          NaN        NaN                 NaN
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 0                     NaN                 NaN                  NaN      NaN
# 1                     NaN                 NaN                  NaN      NaN
# 2                     NaN                 NaN                  NaN      NaN
# 3                     NaN                 NaN                  NaN      NaN
# 4                     NaN                 NaN                  NaN      NaN
# ...                   ...                 ...                  ...      ...
# 138679                NaN                 NaN                  NaN      NaN
# 138680                NaN                 NaN                  NaN      NaN
# 138681                NaN                 NaN                  NaN      NaN
# 138682                NaN                 NaN                  NaN      NaN
# 138683                NaN                 NaN                  NaN      NaN
#
#        OncUnKnow
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 138679       NaN
# 138680       NaN
# 138681       NaN
# 138682       NaN
# 138683       NaN
#
# [138684 rows x 133 columns]

# %%
data = data[data.GroupName == 'Psoriasis']

# %%
data
# Out:
#               date_of_birth  GroupName  age sex    Start_D  DiagYear  \
# 0       1906-05-15 00:00:00  Psoriasis   98   M 2005-08-03    2005.0
# 2       1907-06-15 00:00:00  Psoriasis   95   M 2003-10-12    2003.0
# 4       1909-01-01 00:00:00  Psoriasis  100   M 2009-06-30    2009.0
# 7       1909-05-01 00:00:00  Psoriasis   93   M 2003-04-24    2003.0
# 8       1909-06-09 00:00:00  Psoriasis   94   M 2004-09-20    2004.0
# ...                     ...        ...  ...  ..        ...       ...
# 138674  2016-03-15 00:00:00  Psoriasis    0   M 2017-03-14    2017.0
# 138676  2016-01-29 00:00:00  Psoriasis    1   M 2017-01-02    2017.0
# 138679  2016-01-30 00:00:00  Psoriasis    1   M 2017-03-30    2017.0
# 138681  2016-06-15 00:00:00  Psoriasis    0   M 2017-02-28    2017.0
# 138682  2016-10-13 00:00:00  Psoriasis    0   M 2017-01-13    2017.0
#
#        Infertility             Psoriasis Tuberculosis Tuberculosis s/p  ...  \
# 0               NaN                  NaN          NaN              NaN  ...
# 2               NaN                  NaN          NaN              NaN  ...
# 4               NaN                  NaN          NaN              NaN  ...
# 7               NaN  1999-11-16 00:00:00          NaN              NaN  ...
# 8               NaN  2004-02-23 00:00:00          NaN              NaN  ...
# ...             ...                  ...          ...              ...  ...
# 138674          NaN                  NaN          NaN              NaN  ...
# 138676          NaN                  NaN          NaN              NaN  ...
# 138679          NaN                  NaN          NaN              NaN  ...
# 138681          NaN                  NaN          NaN              NaN  ...
# 138682          NaN                  NaN          NaN              NaN  ...
#
#        OncBone OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 0          NaN         NaN          NaN        NaN                 NaN
# 2          NaN         NaN          NaN        NaN                 NaN
# 4          NaN         NaN          NaN        NaN                 NaN
# 7          NaN         NaN          NaN        NaN                 NaN
# 8          NaN         NaN          NaN        NaN                 NaN
# ...        ...         ...          ...        ...                 ...
# 138674     NaN         NaN          NaN        NaN                 NaN
# 138676     NaN         NaN          NaN        NaN                 NaN
# 138679     NaN         NaN          NaN        NaN                 NaN
# 138681     NaN         NaN          NaN        NaN                 NaN
# 138682     NaN         NaN          NaN        NaN                 NaN
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 0                     NaN                 NaN                  NaN      NaN
# 2                     NaN                 NaN                  NaN      NaN
# 4                     NaN                 NaN                  NaN      NaN
# 7                     NaN                 NaN                  NaN      NaN
# 8                     NaN                 NaN                  NaN      NaN
# ...                   ...                 ...                  ...      ...
# 138674                NaN                 NaN                  NaN      NaN
# 138676                NaN                 NaN                  NaN      NaN
# 138679                NaN                 NaN                  NaN      NaN
# 138681                NaN                 NaN                  NaN      NaN
# 138682                NaN                 NaN                  NaN      NaN
#
#        OncUnKnow
# 0            NaN
# 2            NaN
# 4            NaN
# 7            NaN
# 8            NaN
# ...          ...
# 138674       NaN
# 138676       NaN
# 138679       NaN
# 138681       NaN
# 138682       NaN
#
# [69342 rows x 133 columns]

# %%
data = data[data.Psoriasis.notna()]

# %%
data
# Out:
#               date_of_birth  GroupName age sex    Start_D  DiagYear  \
# 7       1909-05-01 00:00:00  Psoriasis  93   M 2003-04-24    2003.0
# 8       1909-06-09 00:00:00  Psoriasis  94   M 2004-09-20    2004.0
# 25      1911-07-27 00:00:00  Psoriasis  95   M 2007-03-04    2007.0
# 31      1911-05-02 00:00:00  Psoriasis  91   M 2003-04-06    2003.0
# 36      1911-01-01 00:00:00  Psoriasis  94   M 2005-03-13    2005.0
# ...                     ...        ...  ..  ..        ...       ...
# 138362  2013-08-20 00:00:00  Psoriasis   1   M 2015-12-18    2015.0
# 138417  2014-10-03 00:00:00  Psoriasis   0   M 2015-01-25    2015.0
# 138437  2014-07-25 00:00:00  Psoriasis   0   M 2015-12-13    2015.0
# 138562  2015-01-23 00:00:00  Psoriasis   2   M 2017-08-31    2017.0
# 138650  2016-05-13 00:00:00  Psoriasis   0   M 2017-03-12    2017.0
#
#        Infertility             Psoriasis Tuberculosis Tuberculosis s/p  ...  \
# 7               NaN  1999-11-16 00:00:00          NaN              NaN  ...
# 8               NaN  2004-02-23 00:00:00          NaN              NaN  ...
# 25              NaN  2007-04-08 00:00:00          NaN              NaN  ...
# 31              NaN  2000-11-17 00:00:00          NaN              NaN  ...
# 36              NaN  2006-12-06 00:00:00          NaN              NaN  ...
# ...             ...                  ...          ...              ...  ...
# 138362          NaN  2015-12-18 00:00:00          NaN              NaN  ...
# 138417          NaN  2015-01-25 00:00:00          NaN              NaN  ...
# 138437          NaN  2015-11-03 00:00:00          NaN              NaN  ...
# 138562          NaN  2018-02-08 00:00:00          NaN              NaN  ...
# 138650          NaN  2017-03-12 00:00:00          NaN              NaN  ...
#
#        OncBone OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 7          NaN         NaN          NaN        NaN                 NaN
# 8          NaN         NaN          NaN        NaN                 NaN
# 25         NaN         NaN          NaN        NaN                 NaN
# 31         NaN         NaN          NaN        NaN                 NaN
# 36         NaN         NaN          NaN        NaN                 NaN
# ...        ...         ...          ...        ...                 ...
# 138362     NaN         NaN          NaN        NaN                 NaN
# 138417     NaN         NaN          NaN        NaN                 NaN
# 138437     NaN         NaN          NaN        NaN                 NaN
# 138562     NaN         NaN          NaN        NaN                 NaN
# 138650     NaN         NaN          NaN        NaN                 NaN
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 7                     NaN                 NaN                  NaN      NaN
# 8                     NaN                 NaN                  NaN      NaN
# 25                    NaN                 NaN                  NaN      NaN
# 31                    NaN                 NaN                  NaN      NaN
# 36                    NaN                 NaN                  NaN      NaN
# ...                   ...                 ...                  ...      ...
# 138362                NaN                 NaN                  NaN      NaN
# 138417                NaN                 NaN                  NaN      NaN
# 138437                NaN                 NaN                  NaN      NaN
# 138562                NaN                 NaN                  NaN      NaN
# 138650                NaN                 NaN                  NaN      NaN
#
#        OncUnKnow
# 7            NaN
# 8            NaN
# 25           NaN
# 31           NaN
# 36           NaN
# ...          ...
# 138362       NaN
# 138417       NaN
# 138437       NaN
# 138562       NaN
# 138650       NaN
#
# [14528 rows x 133 columns]

# %%
data[pd.to_datetime(data.OncProatate) <= pd.to_datetime(data.Psoriasis)]
# Out:
#              date_of_birth  GroupName age sex    Start_D  DiagYear  \
# 87     1914-01-01 00:00:00  Psoriasis  89   M 2003-04-30    2003.0
# 298    1918-11-01 00:00:00  Psoriasis  86   M 2005-01-25    2005.0
# 870    1921-05-28 00:00:00  Psoriasis  94   M 2016-01-18    2016.0
# 947    1922-08-28 00:00:00  Psoriasis  87   M 2010-06-22    2010.0
# 1569   1923-01-01 00:00:00  Psoriasis  83   M 2006-08-24    2006.0
# ...                    ...        ...  ..  ..        ...       ...
# 45041  1954-10-26 00:00:00  Psoriasis  54   M 2009-06-22    2009.0
# 49701  1956-08-31 00:00:00  Psoriasis  56   M 2013-10-21    2013.0
# 50402  1956-01-12 00:00:00  Psoriasis  60   M 2016-11-08    2016.0
# 50827  1957-04-16 00:00:00  Psoriasis  58   M 2016-02-01    2016.0
# 69325  1967-03-17 00:00:00  Psoriasis  46   M 2014-01-07    2014.0
#
#       Infertility             Psoriasis Tuberculosis Tuberculosis s/p  ...  \
# 87             NaN  2004-01-14 00:00:00          NaN              NaN  ...
# 298            NaN  2012-07-14 00:00:00          NaN              NaN  ...
# 870            NaN  2016-07-01 00:00:00          NaN              NaN  ...
# 947            NaN  2008-03-01 00:00:00          NaN              NaN  ...
# 1569           NaN  2003-03-01 00:00:00          NaN              NaN  ...
# ...            ...                  ...          ...              ...  ...
# 45041          NaN  2015-02-01 00:00:00          NaN              NaN  ...
# 49701          NaN  2014-07-01 00:00:00          NaN              NaN  ...
# 50402          NaN  2016-12-08 00:00:00          NaN              NaN  ...
# 50827          NaN  2016-05-30 00:00:00          NaN              NaN  ...
# 69325          NaN  2017-01-03 00:00:00          NaN              NaN  ...
#
#       OncBone OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 87        NaN         NaN          NaN        NaN                 NaN
# 298       NaN         NaN          NaN        NaN                 NaN
# 870       NaN         NaN          NaN        NaN                 NaN
# 947       NaN         NaN          NaN        NaN                 NaN
# 1569      NaN         NaN          NaN        NaN                 NaN
# ...       ...         ...          ...        ...                 ...
# 45041     NaN         NaN          NaN        NaN                 NaN
# 49701     NaN         NaN          NaN        NaN                 NaN
# 50402     NaN         NaN          NaN        NaN                 NaN
# 50827     NaN         NaN          NaN        NaN                 NaN
# 69325     NaN         NaN          NaN        NaN                 NaN
#
#       OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 87                   NaN                 NaN                  NaN      NaN
# 298                  NaN                 NaN                  NaN      NaN
# 870                  NaN                 NaN                  NaN      NaN
# 947                  NaN                 NaN                  NaN      NaN
# 1569                 NaN                 NaN                  NaN      NaN
# ...                  ...                 ...                  ...      ...
# 45041                NaN                 NaN                  NaN      NaN
# 49701                NaN                 NaN                  NaN      NaN
# 50402                NaN                 NaN                  NaN      NaN
# 50827                NaN                 NaN                  NaN      NaN
# 69325                NaN                 NaN                  NaN      NaN
#
#       OncUnKnow
# 87          NaN
# 298         NaN
# 870         NaN
# 947         NaN
# 1569        NaN
# ...         ...
# 45041       NaN
# 49701       NaN
# 50402       NaN
# 50827       NaN
# 69325       NaN
#
# [121 rows x 133 columns]

# %%
data[pd.to_datetime(data.OncProatate) > pd.to_datetime(data.Psoriasis)]
# Out:
#              date_of_birth  GroupName age sex    Start_D  DiagYear  \
# 124    1915-01-01 00:00:00  Psoriasis  87   M 2003-01-06    2003.0
# 689    1920-01-01 00:00:00  Psoriasis  83   M 2003-12-14    2003.0
# 923    1921-12-19 00:00:00  Psoriasis  81   M 2003-12-03    2003.0
# 1007   1922-10-29 00:00:00  Psoriasis  87   M 2010-06-07    2010.0
# 1009   1922-01-22 00:00:00  Psoriasis  85   M 2007-04-17    2007.0
# ...                    ...        ...  ..  ..        ...       ...
# 59607  1961-12-26 00:00:00  Psoriasis  49   M 2011-11-28    2011.0
# 60065  1961-04-29 00:00:00  Psoriasis  46   M 2008-04-16    2008.0
# 60589  1961-01-22 00:00:00  Psoriasis  43   M 2004-08-19    2004.0
# 63325  1963-12-06 00:00:00  Psoriasis  53   M 2017-05-07    2017.0
# 64663  1964-02-11 00:00:00  Psoriasis  38   M 2003-02-23    2003.0
#
#       Infertility             Psoriasis Tuberculosis Tuberculosis s/p  ...  \
# 124            NaN  2003-10-19 00:00:00          NaN              NaN  ...
# 689            NaN  2003-12-14 00:00:00          NaN              NaN  ...
# 923            NaN  2003-04-01 00:00:00          NaN              NaN  ...
# 1007           NaN  2003-11-03 00:00:00          NaN              NaN  ...
# 1009           NaN  2000-06-06 00:00:00          NaN              NaN  ...
# ...            ...                  ...          ...              ...  ...
# 59607          NaN  2008-01-16 00:00:00          NaN              NaN  ...
# 60065          NaN  2002-10-22 00:00:00          NaN              NaN  ...
# 60589          NaN  2000-01-01 00:00:00          NaN              NaN  ...
# 63325          NaN  2017-05-10 00:00:00          NaN              NaN  ...
# 64663          NaN  2001-12-01 00:00:00          NaN              NaN  ...
#
#       OncBone          OncSaracoma OncGenitalia Oncmyeloma  \
# 124       NaN                  NaN          NaN        NaN
# 689       NaN                  NaN          NaN        NaN
# 923       NaN  2010-12-29 00:00:00          NaN        NaN
# 1007      NaN                  NaN          NaN        NaN
# 1009      NaN                  NaN          NaN        NaN
# ...       ...                  ...          ...        ...
# 59607     NaN                  NaN          NaN        NaN
# 60065     NaN                  NaN          NaN        NaN
# 60589     NaN                  NaN          NaN        NaN
# 63325     NaN                  NaN          NaN        NaN
# 64663     NaN                  NaN          NaN        NaN
#
#       OncPolycythemiaVera OncMyelodysplastic OncLympholiferative  \
# 124                   NaN                NaN                 NaN
# 689                   NaN                NaN                 NaN
# 923                   NaN                NaN                 NaN
# 1007                  NaN                NaN                 NaN
# 1009                  NaN                NaN                 NaN
# ...                   ...                ...                 ...
# 59607                 NaN                NaN                 NaN
# 60065                 NaN                NaN                 NaN
# 60589                 NaN                NaN                 NaN
# 63325                 NaN                NaN                 NaN
# 64663                 NaN                NaN                 NaN
#
#       OncNeurofibromatosis OncOther OncUnKnow
# 124                    NaN      NaN       NaN
# 689                    NaN      NaN       NaN
# 923                    NaN      NaN       NaN
# 1007                   NaN      NaN       NaN
# 1009                   NaN      NaN       NaN
# ...                    ...      ...       ...
# 59607                  NaN      NaN       NaN
# 60065                  NaN      NaN       NaN
# 60589                  NaN      NaN       NaN
# 63325                  NaN      NaN       NaN
# 64663                  NaN      NaN       NaN
#
# [239 rows x 133 columns]

# %%
data[data.OncProatate.isna()]
# Out:
#               date_of_birth  GroupName age sex    Start_D  DiagYear  \
# 7       1909-05-01 00:00:00  Psoriasis  93   M 2003-04-24    2003.0
# 8       1909-06-09 00:00:00  Psoriasis  94   M 2004-09-20    2004.0
# 25      1911-07-27 00:00:00  Psoriasis  95   M 2007-03-04    2007.0
# 31      1911-05-02 00:00:00  Psoriasis  91   M 2003-04-06    2003.0
# 36      1911-01-01 00:00:00  Psoriasis  94   M 2005-03-13    2005.0
# ...                     ...        ...  ..  ..        ...       ...
# 138362  2013-08-20 00:00:00  Psoriasis   1   M 2015-12-18    2015.0
# 138417  2014-10-03 00:00:00  Psoriasis   0   M 2015-01-25    2015.0
# 138437  2014-07-25 00:00:00  Psoriasis   0   M 2015-12-13    2015.0
# 138562  2015-01-23 00:00:00  Psoriasis   2   M 2017-08-31    2017.0
# 138650  2016-05-13 00:00:00  Psoriasis   0   M 2017-03-12    2017.0
#
#        Infertility             Psoriasis Tuberculosis Tuberculosis s/p  ...  \
# 7               NaN  1999-11-16 00:00:00          NaN              NaN  ...
# 8               NaN  2004-02-23 00:00:00          NaN              NaN  ...
# 25              NaN  2007-04-08 00:00:00          NaN              NaN  ...
# 31              NaN  2000-11-17 00:00:00          NaN              NaN  ...
# 36              NaN  2006-12-06 00:00:00          NaN              NaN  ...
# ...             ...                  ...          ...              ...  ...
# 138362          NaN  2015-12-18 00:00:00          NaN              NaN  ...
# 138417          NaN  2015-01-25 00:00:00          NaN              NaN  ...
# 138437          NaN  2015-11-03 00:00:00          NaN              NaN  ...
# 138562          NaN  2018-02-08 00:00:00          NaN              NaN  ...
# 138650          NaN  2017-03-12 00:00:00          NaN              NaN  ...
#
#        OncBone OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 7          NaN         NaN          NaN        NaN                 NaN
# 8          NaN         NaN          NaN        NaN                 NaN
# 25         NaN         NaN          NaN        NaN                 NaN
# 31         NaN         NaN          NaN        NaN                 NaN
# 36         NaN         NaN          NaN        NaN                 NaN
# ...        ...         ...          ...        ...                 ...
# 138362     NaN         NaN          NaN        NaN                 NaN
# 138417     NaN         NaN          NaN        NaN                 NaN
# 138437     NaN         NaN          NaN        NaN                 NaN
# 138562     NaN         NaN          NaN        NaN                 NaN
# 138650     NaN         NaN          NaN        NaN                 NaN
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 7                     NaN                 NaN                  NaN      NaN
# 8                     NaN                 NaN                  NaN      NaN
# 25                    NaN                 NaN                  NaN      NaN
# 31                    NaN                 NaN                  NaN      NaN
# 36                    NaN                 NaN                  NaN      NaN
# ...                   ...                 ...                  ...      ...
# 138362                NaN                 NaN                  NaN      NaN
# 138417                NaN                 NaN                  NaN      NaN
# 138437                NaN                 NaN                  NaN      NaN
# 138562                NaN                 NaN                  NaN      NaN
# 138650                NaN                 NaN                  NaN      NaN
#
#        OncUnKnow
# 7            NaN
# 8            NaN
# 25           NaN
# 31           NaN
# 36           NaN
# ...          ...
# 138362       NaN
# 138417       NaN
# 138437       NaN
# 138562       NaN
# 138650       NaN
#
# [14168 rows x 133 columns]

# %%
data[pd.to_datetime(data['Prostatic Hypertrophy']) <= pd.to_datetime(data.Psoriasis)]
# Out:
#              date_of_birth  GroupName age sex    Start_D  DiagYear  \
# 36     1911-01-01 00:00:00  Psoriasis  94   M 2005-03-13    2005.0
# 77     1914-03-01 00:00:00  Psoriasis  93   M 2008-01-14    2008.0
# 87     1914-01-01 00:00:00  Psoriasis  89   M 2003-04-30    2003.0
# 123    1915-04-01 00:00:00  Psoriasis  94   M 2009-09-22    2009.0
# 128    1915-02-22 00:00:00  Psoriasis  89   M 2005-08-15    2005.0
# ...                    ...        ...  ..  ..        ...       ...
# 63436  1963-03-24 00:00:00  Psoriasis  44   M 2008-02-01    2008.0
# 63834  1963-11-08 00:00:00  Psoriasis  52   M 2016-03-16    2016.0
# 68033  1966-07-05 00:00:00  Psoriasis  44   M 2011-02-13    2011.0
# 80580  1973-05-04 00:00:00  Psoriasis  31   M 2005-02-23    2005.0
# 81709  1973-11-09 00:00:00  Psoriasis  39   M 2013-09-20    2013.0
#
#               Infertility             Psoriasis Tuberculosis Tuberculosis s/p  \
# 36                     NaN  2006-12-06 00:00:00          NaN              NaN
# 77                     NaN  2003-03-29 00:00:00          NaN              NaN
# 87                     NaN  2004-01-14 00:00:00          NaN              NaN
# 123                    NaN  2011-05-01 00:00:00          NaN              NaN
# 128                    NaN  2010-11-01 00:00:00          NaN              NaN
# ...                    ...                  ...          ...              ...
# 63436                  NaN  2008-02-01 00:00:00          NaN              NaN
# 63834                  NaN  2016-03-20 00:00:00          NaN              NaN
# 68033  2004-12-02 00:00:00  2014-01-01 00:00:00          NaN              NaN
# 80580                  NaN  2015-08-19 00:00:00          NaN              NaN
# 81709                  NaN  2011-10-01 00:00:00          NaN              NaN
#
#        ... OncBone OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 36     ...     NaN         NaN          NaN        NaN                 NaN
# 77     ...     NaN         NaN          NaN        NaN                 NaN
# 87     ...     NaN         NaN          NaN        NaN                 NaN
# 123    ...     NaN         NaN          NaN        NaN                 NaN
# 128    ...     NaN         NaN          NaN        NaN                 NaN
# ...    ...     ...         ...          ...        ...                 ...
# 63436  ...     NaN         NaN          NaN        NaN                 NaN
# 63834  ...     NaN         NaN          NaN        NaN                 NaN
# 68033  ...     NaN         NaN          NaN        NaN                 NaN
# 80580  ...     NaN         NaN          NaN        NaN                 NaN
# 81709  ...     NaN         NaN          NaN        NaN                 NaN
#
#       OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 36                   NaN                 NaN                  NaN      NaN
# 77                   NaN                 NaN                  NaN      NaN
# 87                   NaN                 NaN                  NaN      NaN
# 123                  NaN                 NaN                  NaN      NaN
# 128                  NaN                 NaN                  NaN      NaN
# ...                  ...                 ...                  ...      ...
# 63436                NaN                 NaN                  NaN      NaN
# 63834                NaN                 NaN                  NaN      NaN
# 68033                NaN                 NaN                  NaN      NaN
# 80580                NaN                 NaN                  NaN      NaN
# 81709                NaN                 NaN                  NaN      NaN
#
#       OncUnKnow
# 36          NaN
# 77          NaN
# 87          NaN
# 123         NaN
# 128         NaN
# ...         ...
# 63436       NaN
# 63834       NaN
# 68033       NaN
# 80580       NaN
# 81709       NaN
#
# [1054 rows x 133 columns]

# %%
data[pd.to_datetime(data['Prostatic Hypertrophy']) > pd.to_datetime(data.Psoriasis)]
# Out:
#               date_of_birth  GroupName age sex    Start_D  DiagYear  \
# 104     1915-02-11 00:00:00  Psoriasis  93   M 2009-10-27    2009.0
# 115     1915-12-10 00:00:00  Psoriasis  93   M 2009-03-22    2009.0
# 177     1916-12-20 00:00:00  Psoriasis  85   M 2002-10-31    2002.0
# 183     1916-06-02 00:00:00  Psoriasis  91   M 2008-06-15    2008.0
# 203     1917-01-01 00:00:00  Psoriasis  88   M 2005-03-03    2005.0
# ...                     ...        ...  ..  ..        ...       ...
# 70347   1967-05-29 00:00:00  Psoriasis  40   M 2008-11-04    2008.0
# 80454   1973-07-30 00:00:00  Psoriasis  34   M 2008-11-06    2008.0
# 86264   1975-01-24 00:00:00  Psoriasis  29   M 2004-05-09    2004.0
# 91057   1977-12-10 00:00:00  Psoriasis  29   M 2007-04-25    2007.0
# 103747  1982-06-09 00:00:00  Psoriasis  21   M 2004-01-28    2004.0
#
#        Infertility             Psoriasis Tuberculosis Tuberculosis s/p  ...  \
# 104             NaN  2002-01-31 00:00:00          NaN              NaN  ...
# 115             NaN  2007-07-01 00:00:00          NaN              NaN  ...
# 177             NaN  1980-05-01 00:00:00          NaN              NaN  ...
# 183             NaN  2006-05-07 00:00:00          NaN              NaN  ...
# 203             NaN  2002-09-01 00:00:00          NaN              NaN  ...
# ...             ...                  ...          ...              ...  ...
# 70347           NaN  2009-01-01 00:00:00          NaN              NaN  ...
# 80454           NaN  2010-02-01 00:00:00          NaN              NaN  ...
# 86264           NaN  2004-09-01 00:00:00          NaN              NaN  ...
# 91057           NaN  2002-01-24 00:00:00          NaN              NaN  ...
# 103747          NaN  2005-05-01 00:00:00          NaN              NaN  ...
#
#        OncBone OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 104        NaN         NaN          NaN        NaN                 NaN
# 115        NaN         NaN          NaN        NaN                 NaN
# 177        NaN         NaN          NaN        NaN                 NaN
# 183        NaN         NaN          NaN        NaN                 NaN
# 203        NaN         NaN          NaN        NaN                 NaN
# ...        ...         ...          ...        ...                 ...
# 70347      NaN         NaN          NaN        NaN                 NaN
# 80454      NaN         NaN          NaN        NaN                 NaN
# 86264      NaN         NaN          NaN        NaN                 NaN
# 91057      NaN         NaN          NaN        NaN                 NaN
# 103747     NaN         NaN          NaN        NaN                 NaN
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 104                   NaN                 NaN                  NaN      NaN
# 115                   NaN                 NaN                  NaN      NaN
# 177                   NaN                 NaN                  NaN      NaN
# 183                   NaN                 NaN                  NaN      NaN
# 203                   NaN                 NaN                  NaN      NaN
# ...                   ...                 ...                  ...      ...
# 70347                 NaN                 NaN                  NaN      NaN
# 80454                 NaN                 NaN                  NaN      NaN
# 86264                 NaN                 NaN                  NaN      NaN
# 91057                 NaN                 NaN                  NaN      NaN
# 103747                NaN                 NaN                  NaN      NaN
#
#                   OncUnKnow
# 104                     NaN
# 115                     NaN
# 177                     NaN
# 183                     NaN
# 203     2005-01-01 00:00:00
# ...                     ...
# 70347                   NaN
# 80454                   NaN
# 86264                   NaN
# 91057                   NaN
# 103747                  NaN
#
# [894 rows x 133 columns]

# %% [markdown]
# ## Controllo - Fertile/Infertile

# %%
data = df[selected_columns]
data = data[data.sex == 'M']
data = data[data.GroupName == 'Control']
data
# Out:
#               date_of_birth GroupName  age sex    Start_D  DiagYear  \
# 1       1906-06-15 00:00:00   Control   98   M 2005-08-03    2005.0
# 3       1907-05-14 00:00:00   Control   95   M 2003-10-12    2003.0
# 5       1909-04-01 00:00:00   Control  100   M 2009-06-30    2009.0
# 6       1909-09-09 00:00:00   Control   93   M 2003-04-24    2003.0
# 9       1909-09-25 00:00:00   Control   94   M 2004-09-20    2004.0
# ...                     ...       ...  ...  ..        ...       ...
# 138675  2016-05-13 00:00:00   Control    0   M 2017-03-14    2017.0
# 138677  2016-07-08 00:00:00   Control    0   M 2017-01-02    2017.0
# 138678  2016-10-20 00:00:00   Control    0   M 2017-03-30    2017.0
# 138680  2016-05-25 00:00:00   Control    0   M 2017-02-28    2017.0
# 138683  2016-06-18 00:00:00   Control    0   M 2017-01-13    2017.0
#
#        Infertility  Psoriasis Tuberculosis Tuberculosis s/p  ... OncBone  \
# 1               NaN       NaN          NaN              NaN  ...     NaN
# 3               NaN       NaN          NaN              NaN  ...     NaN
# 5               NaN       NaN          NaN              NaN  ...     NaN
# 6               NaN       NaN          NaN              NaN  ...     NaN
# 9               NaN       NaN          NaN              NaN  ...     NaN
# ...             ...       ...          ...              ...  ...     ...
# 138675          NaN       NaN          NaN              NaN  ...     NaN
# 138677          NaN       NaN          NaN              NaN  ...     NaN
# 138678          NaN       NaN          NaN              NaN  ...     NaN
# 138680          NaN       NaN          NaN              NaN  ...     NaN
# 138683          NaN       NaN          NaN              NaN  ...     NaN
#
#        OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 1              NaN          NaN        NaN                 NaN
# 3              NaN          NaN        NaN                 NaN
# 5              NaN          NaN        NaN                 NaN
# 6              NaN          NaN        NaN                 NaN
# 9              NaN          NaN        NaN                 NaN
# ...            ...          ...        ...                 ...
# 138675         NaN          NaN        NaN                 NaN
# 138677         NaN          NaN        NaN                 NaN
# 138678         NaN          NaN        NaN                 NaN
# 138680         NaN          NaN        NaN                 NaN
# 138683         NaN          NaN        NaN                 NaN
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 1                     NaN                 NaN                  NaN      NaN
# 3                     NaN                 NaN                  NaN      NaN
# 5                     NaN                 NaN                  NaN      NaN
# 6                     NaN                 NaN                  NaN      NaN
# 9                     NaN                 NaN                  NaN      NaN
# ...                   ...                 ...                  ...      ...
# 138675                NaN                 NaN                  NaN      NaN
# 138677                NaN                 NaN                  NaN      NaN
# 138678                NaN                 NaN                  NaN      NaN
# 138680                NaN                 NaN                  NaN      NaN
# 138683                NaN                 NaN                  NaN      NaN
#
#                   OncUnKnow
# 1                       NaN
# 3                       NaN
# 5                       NaN
# 6       2001-10-31 00:00:00
# 9                       NaN
# ...                     ...
# 138675                  NaN
# 138677                  NaN
# 138678                  NaN
# 138680                  NaN
# 138683                  NaN
#
# [69342 rows x 133 columns]

# %%
# considerare condizioni pre-esistenti alla diagnosi di infertilità
# Converting date columns to datetime for comparison
data['Infertility '] = pd.to_datetime(data['Infertility '], errors='coerce')


# Identify comorbidity columns, assuming they start from "Tuberculosis" onwards
comorbidity_columns = data.columns[data.columns.get_loc("Tuberculosis"):]

# Iterate through comorbidity columns to adjust dates
for column in comorbidity_columns:
    data[column] = pd.to_datetime(data[column], errors='coerce')
    # Replace the date with NaN if it occurs after the relevant reference date
    data[column] = data.apply(
        lambda row: (
            row[column] if pd.isna(row[column]) or (
                (row['GroupName'] == 'Control' and row[column] <= row['Infertility ']) 
            ) else pd.NaT
        ), 
        axis=1
    )

# %%
data
# Out:
#               date_of_birth GroupName  age sex    Start_D  DiagYear  \
# 1       1906-06-15 00:00:00   Control   98   M 2005-08-03    2005.0
# 3       1907-05-14 00:00:00   Control   95   M 2003-10-12    2003.0
# 5       1909-04-01 00:00:00   Control  100   M 2009-06-30    2009.0
# 6       1909-09-09 00:00:00   Control   93   M 2003-04-24    2003.0
# 9       1909-09-25 00:00:00   Control   94   M 2004-09-20    2004.0
# ...                     ...       ...  ...  ..        ...       ...
# 138675  2016-05-13 00:00:00   Control    0   M 2017-03-14    2017.0
# 138677  2016-07-08 00:00:00   Control    0   M 2017-01-02    2017.0
# 138678  2016-10-20 00:00:00   Control    0   M 2017-03-30    2017.0
# 138680  2016-05-25 00:00:00   Control    0   M 2017-02-28    2017.0
# 138683  2016-06-18 00:00:00   Control    0   M 2017-01-13    2017.0
#
#        Infertility  Psoriasis Tuberculosis Tuberculosis s/p  ... OncBone  \
# 1               NaT       NaN          NaT              NaT  ...     NaT
# 3               NaT       NaN          NaT              NaT  ...     NaT
# 5               NaT       NaN          NaT              NaT  ...     NaT
# 6               NaT       NaN          NaT              NaT  ...     NaT
# 9               NaT       NaN          NaT              NaT  ...     NaT
# ...             ...       ...          ...              ...  ...     ...
# 138675          NaT       NaN          NaT              NaT  ...     NaT
# 138677          NaT       NaN          NaT              NaT  ...     NaT
# 138678          NaT       NaN          NaT              NaT  ...     NaT
# 138680          NaT       NaN          NaT              NaT  ...     NaT
# 138683          NaT       NaN          NaT              NaT  ...     NaT
#
#        OncSaracoma OncGenitalia Oncmyeloma OncPolycythemiaVera  \
# 1              NaT          NaT        NaT                 NaT
# 3              NaT          NaT        NaT                 NaT
# 5              NaT          NaT        NaT                 NaT
# 6              NaT          NaT        NaT                 NaT
# 9              NaT          NaT        NaT                 NaT
# ...            ...          ...        ...                 ...
# 138675         NaT          NaT        NaT                 NaT
# 138677         NaT          NaT        NaT                 NaT
# 138678         NaT          NaT        NaT                 NaT
# 138680         NaT          NaT        NaT                 NaT
# 138683         NaT          NaT        NaT                 NaT
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 1                     NaT                 NaT                  NaT      NaT
# 3                     NaT                 NaT                  NaT      NaT
# 5                     NaT                 NaT                  NaT      NaT
# 6                     NaT                 NaT                  NaT      NaT
# 9                     NaT                 NaT                  NaT      NaT
# ...                   ...                 ...                  ...      ...
# 138675                NaT                 NaT                  NaT      NaT
# 138677                NaT                 NaT                  NaT      NaT
# 138678                NaT                 NaT                  NaT      NaT
# 138680                NaT                 NaT                  NaT      NaT
# 138683                NaT                 NaT                  NaT      NaT
#
#        OncUnKnow
# 1            NaT
# 3            NaT
# 5            NaT
# 6            NaT
# 9            NaT
# ...          ...
# 138675       NaT
# 138677       NaT
# 138678       NaT
# 138680       NaT
# 138683       NaT
#
# [69342 rows x 133 columns]

# %%
data_control_Infertile = data[data['Infertility '].notna()]
data_control_Infertile['Age at Infertile Diagnosis'] = (pd.to_datetime(data_control_Infertile['Infertility ']) - pd.to_datetime(data_control_Infertile.date_of_birth)).dt.days/365.25
data_control_Infertile['Age at Infertile Diagnosis'] = data_control_Infertile['Age at Infertile Diagnosis'].astype(int)
# Out:
# <ipython-input-167-cd34b28034cc>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_control_Infertile['Age at Infertile Diagnosis'] = (pd.to_datetime(data_control_Infertile['Infertility ']) - pd.to_datetime(data_control_Infertile.date_of_birth)).dt.days/365.25
# <ipython-input-167-cd34b28034cc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_control_Infertile['Age at Infertile Diagnosis'] = (pd.to_datetime(data_control_Infertile['Infertility ']) - pd.to_datetime(data_control_Infertile.date_of_birth)).dt.days/365.25
# <ipython-input-167-cd34b28034cc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_control_Infertile['Age at Infertile Diagnosis'] = data_control_Infertile['Age at Infertile Diagnosis'].astype(int)

# %%
data_control_Infertile = data_control_Infertile[data_control_Infertile['Age at Infertile Diagnosis'] != 0]

# %%
data_control_Infertile
# Out:
#               date_of_birth GroupName age sex    Start_D  DiagYear  \
# 1592    1923-04-01 00:00:00   Control  82   M 2006-03-01    2006.0
# 1809    1924-06-20 00:00:00   Control  85   M 2010-10-03    2010.0
# 2792    1926-01-01 00:00:00   Control  82   M 2008-09-03    2008.0
# 3451    1927-04-10 00:00:00   Control  77   M 2005-09-12    2005.0
# 4152    1928-01-01 00:00:00   Control  79   M 2007-07-01    2007.0
# ...                     ...       ...  ..  ..        ...       ...
# 115527  1987-12-05 00:00:00   Control  16   M 2004-12-21    2004.0
# 115551  1987-11-03 00:00:00   Control  27   M 2015-08-07    2015.0
# 116774  1988-01-24 00:00:00   Control  17   M 2005-03-23    2005.0
# 116798  1988-09-04 00:00:00   Control  25   M 2014-12-15    2014.0
# 124273  1993-01-19 00:00:00   Control  12   M 2005-04-19    2005.0
#
#        Infertility  Psoriasis Tuberculosis Tuberculosis s/p  ...  \
# 1592     2004-09-17       NaN          NaT       1999-12-19  ...
# 1809     2002-01-28       NaN          NaT              NaT  ...
# 2792     2004-03-24       NaN          NaT              NaT  ...
# 3451     2003-02-02       NaN          NaT              NaT  ...
# 4152     2001-04-24       NaN          NaT              NaT  ...
# ...             ...       ...          ...              ...  ...
# 115527   2008-03-01       NaN          NaT              NaT  ...
# 115551   2016-09-26       NaN          NaT              NaT  ...
# 116774   2013-03-18       NaN          NaT              NaT  ...
# 116798   2017-11-01       NaN          NaT              NaT  ...
# 124273   2017-10-09       NaN          NaT              NaT  ...
#
#        OncGenitalia_status_status Oncmyeloma_status_status  \
# 1592                            1                        1
# 1809                            1                        1
# 2792                            1                        1
# 3451                            1                        1
# 4152                            1                        1
# ...                           ...                      ...
# 115527                          1                        1
# 115551                          1                        1
# 116774                          1                        1
# 116798                          1                        1
# 124273                          1                        1
#
#        OncPolycythemiaVera_status_status OncMyelodysplastic_status_status  \
# 1592                                   1                                1
# 1809                                   1                                1
# 2792                                   1                                1
# 3451                                   1                                1
# 4152                                   1                                1
# ...                                  ...                              ...
# 115527                                 1                                1
# 115551                                 1                                1
# 116774                                 1                                1
# 116798                                 1                                1
# 124273                                 1                                1
#
#        OncLympholiferative_status_status OncNeurofibromatosis_status_status  \
# 1592                                   1                                  1
# 1809                                   1                                  1
# 2792                                   1                                  1
# 3451                                   1                                  1
# 4152                                   1                                  1
# ...                                  ...                                ...
# 115527                                 1                                  1
# 115551                                 1                                  1
# 116774                                 1                                  1
# 116798                                 1                                  1
# 124273                                 1                                  1
#
#        OncOther_status_status OncUnKnow_status_status  \
# 1592                        1                       1
# 1809                        1                       1
# 2792                        1                       1
# 3451                        1                       1
# 4152                        1                       1
# ...                       ...                     ...
# 115527                      1                       1
# 115551                      1                       1
# 116774                      1                       1
# 116798                      1                       1
# 124273                      1                       1
#
#        Infertility_Status_status_status Age at Infertile Diagnosis
# 1592                                  1                         81
# 1809                                  1                         77
# 2792                                  1                         78
# 3451                                  1                         75
# 4152                                  1                         73
# ...                                 ...                        ...
# 115527                                1                         20
# 115551                                1                         28
# 116774                                1                         25
# 116798                                1                         29
# 124273                                1                         24
#
# [395 rows x 387 columns]

# %%
data[data['Infertility '].isna()]
# Out:
#               date_of_birth GroupName  age sex    Start_D  DiagYear  \
# 1       1906-06-15 00:00:00   Control   98   M 2005-08-03    2005.0
# 3       1907-05-14 00:00:00   Control   95   M 2003-10-12    2003.0
# 5       1909-04-01 00:00:00   Control  100   M 2009-06-30    2009.0
# 6       1909-09-09 00:00:00   Control   93   M 2003-04-24    2003.0
# 9       1909-09-25 00:00:00   Control   94   M 2004-09-20    2004.0
# ...                     ...       ...  ...  ..        ...       ...
# 138675  2016-05-13 00:00:00   Control    0   M 2017-03-14    2017.0
# 138677  2016-07-08 00:00:00   Control    0   M 2017-01-02    2017.0
# 138678  2016-10-20 00:00:00   Control    0   M 2017-03-30    2017.0
# 138680  2016-05-25 00:00:00   Control    0   M 2017-02-28    2017.0
# 138683  2016-06-18 00:00:00   Control    0   M 2017-01-13    2017.0
#
#        Infertility  Psoriasis Tuberculosis Tuberculosis s/p  ...  \
# 1               NaT       NaN          NaT              NaT  ...
# 3               NaT       NaN          NaT              NaT  ...
# 5               NaT       NaN          NaT              NaT  ...
# 6               NaT       NaN          NaT              NaT  ...
# 9               NaT       NaN          NaT              NaT  ...
# ...             ...       ...          ...              ...  ...
# 138675          NaT       NaN          NaT              NaT  ...
# 138677          NaT       NaN          NaT              NaT  ...
# 138678          NaT       NaN          NaT              NaT  ...
# 138680          NaT       NaN          NaT              NaT  ...
# 138683          NaT       NaN          NaT              NaT  ...
#
#        OncSaracoma_status_status OncGenitalia_status_status  \
# 1                              1                          1
# 3                              1                          1
# 5                              1                          1
# 6                              1                          1
# 9                              1                          1
# ...                          ...                        ...
# 138675                         1                          1
# 138677                         1                          1
# 138678                         1                          1
# 138680                         1                          1
# 138683                         1                          1
#
#        Oncmyeloma_status_status OncPolycythemiaVera_status_status  \
# 1                             1                                 1
# 3                             1                                 1
# 5                             1                                 1
# 6                             1                                 1
# 9                             1                                 1
# ...                         ...                               ...
# 138675                        1                                 1
# 138677                        1                                 1
# 138678                        1                                 1
# 138680                        1                                 1
# 138683                        1                                 1
#
#        OncMyelodysplastic_status_status OncLympholiferative_status_status  \
# 1                                     1                                 1
# 3                                     1                                 1
# 5                                     1                                 1
# 6                                     1                                 1
# 9                                     1                                 1
# ...                                 ...                               ...
# 138675                                1                                 1
# 138677                                1                                 1
# 138678                                1                                 1
# 138680                                1                                 1
# 138683                                1                                 1
#
#        OncNeurofibromatosis_status_status OncOther_status_status  \
# 1                                       1                      1
# 3                                       1                      1
# 5                                       1                      1
# 6                                       1                      1
# 9                                       1                      1
# ...                                   ...                    ...
# 138675                                  1                      1
# 138677                                  1                      1
# 138678                                  1                      1
# 138680                                  1                      1
# 138683                                  1                      1
#
#        OncUnKnow_status_status Infertility_Status_status_status
# 1                            1                                1
# 3                            1                                1
# 5                            1                                1
# 6                            1                                1
# 9                            1                                1
# ...                        ...                              ...
# 138675                       1                                1
# 138677                       1                                1
# 138678                       1                                1
# 138680                       1                                1
# 138683                       1                                1
#
# [68946 rows x 386 columns]

# %%
# Filter for control patients without infertility diagnosis
data_control_no_infertile = data[data['Infertility '].isna()]

# To keep track of used patients (by index) in the non-infertile dataset
used_indices = set()

# To store the matched results
matched_controls = []

# Iterate over each infertile patient in data_control_Infertile
for idx, infertile_row in data_control_Infertile.iterrows():
    age_to_match = infertile_row['Age at Infertile Diagnosis']
    
    # Find a patient from data_control_no_infertile with the same age, excluding already used patients
    potential_matches = data_control_no_infertile[(data_control_no_infertile['age'] == age_to_match) & (~data_control_no_infertile.index.isin(used_indices))]
    
    if not potential_matches.empty:
        # Take the first available match
        matched_row = potential_matches.iloc[0]
        
        # Append the matched row to the list
        matched_controls.append(matched_row)
        
        # Add the index of the matched patient to the set of used indices
        used_indices.add(matched_row.name)

# Convert the matched controls to a DataFrame for better viewing
matched_controls_df = pd.DataFrame(matched_controls)

# Check if all patients in the infertile dataset have been matched
if len(matched_controls_df) == len(data_control_Infertile):
    print("Successfully matched all patients.")
else:
    print(f"Only {len(matched_controls_df)} out of {len(data_control_Infertile)} patients were successfully matched.")
# Out:
# Only 393 out of 395 patients were successfully matched.

# %%
matched_controls_df
# Out:
#        date_of_birth GroupName  age sex    Start_D  DiagYear Infertility   \
# 485       1920-11-24   Control   81   M 2002-11-21    2002.0          NaT
# 1840      1924-04-15   Control   77   M 2002-11-19    2002.0          NaT
# 1317      1923-09-14   Control   78   M 2002-10-09    2002.0          NaT
# 2923      1926-05-15   Control   75   M 2002-09-22    2002.0          NaT
# 3805      1928-10-27   Control   73   M 2002-11-26    2002.0          NaT
# ...              ...       ...  ...  ..        ...       ...          ...
# 100191    1981-11-26   Control   20   M 2002-12-30    2002.0          NaT
# 82716     1974-12-17   Control   28   M 2003-02-09    2003.0          NaT
# 89482     1977-09-13   Control   25   M 2003-04-15    2003.0          NaT
# 80077     1973-11-03   Control   29   M 2003-05-25    2003.0          NaT
# 91877     1977-09-02   Control   24   M 2002-11-08    2002.0          NaT
#
#        Psoriasis Tuberculosis Tuberculosis s/p  ... OncSaracoma_status_status  \
# 485          NaT          NaT              NaT  ...                         1
# 1840         NaT          NaT              NaT  ...                         1
# 1317         NaT          NaT              NaT  ...                         1
# 2923         NaT          NaT              NaT  ...                         1
# 3805         NaT          NaT              NaT  ...                         1
# ...          ...          ...              ...  ...                       ...
# 100191       NaT          NaT              NaT  ...                         1
# 82716        NaT          NaT              NaT  ...                         1
# 89482        NaT          NaT              NaT  ...                         1
# 80077        NaT          NaT              NaT  ...                         1
# 91877        NaT          NaT              NaT  ...                         1
#
#        OncGenitalia_status_status Oncmyeloma_status_status  \
# 485                             1                        1
# 1840                            1                        1
# 1317                            1                        1
# 2923                            1                        1
# 3805                            1                        1
# ...                           ...                      ...
# 100191                          1                        1
# 82716                           1                        1
# 89482                           1                        1
# 80077                           1                        1
# 91877                           1                        1
#
#        OncPolycythemiaVera_status_status OncMyelodysplastic_status_status  \
# 485                                    1                                1
# 1840                                   1                                1
# 1317                                   1                                1
# 2923                                   1                                1
# 3805                                   1                                1
# ...                                  ...                              ...
# 100191                                 1                                1
# 82716                                  1                                1
# 89482                                  1                                1
# 80077                                  1                                1
# 91877                                  1                                1
#
#        OncLympholiferative_status_status OncNeurofibromatosis_status_status  \
# 485                                    1                                  1
# 1840                                   1                                  1
# 1317                                   1                                  1
# 2923                                   1                                  1
# 3805                                   1                                  1
# ...                                  ...                                ...
# 100191                                 1                                  1
# 82716                                  1                                  1
# 89482                                  1                                  1
# 80077                                  1                                  1
# 91877                                  1                                  1
#
#        OncOther_status_status OncUnKnow_status_status  \
# 485                         1                       1
# 1840                        1                       1
# 1317                        1                       1
# 2923                        1                       1
# 3805                        1                       1
# ...                       ...                     ...
# 100191                      1                       1
# 82716                       1                       1
# 89482                       1                       1
# 80077                       1                       1
# 91877                       1                       1
#
#        Infertility_Status_status_status
# 485                                   1
# 1840                                  1
# 1317                                  1
# 2923                                  1
# 3805                                  1
# ...                                 ...
# 100191                                1
# 82716                                 1
# 89482                                 1
# 80077                                 1
# 91877                                 1
#
# [393 rows x 386 columns]

# %%
df_concatenated = pd.concat([matched_controls_df, data_control_Infertile], axis=0)

# %%
df_concatenated
# Out:
#               date_of_birth GroupName age sex    Start_D  DiagYear  \
# 485     1920-11-24 00:00:00   Control  81   M 2002-11-21    2002.0
# 1840    1924-04-15 00:00:00   Control  77   M 2002-11-19    2002.0
# 1317    1923-09-14 00:00:00   Control  78   M 2002-10-09    2002.0
# 2923    1926-05-15 00:00:00   Control  75   M 2002-09-22    2002.0
# 3805    1928-10-27 00:00:00   Control  73   M 2002-11-26    2002.0
# ...                     ...       ...  ..  ..        ...       ...
# 115527  1987-12-05 00:00:00   Control  16   M 2004-12-21    2004.0
# 115551  1987-11-03 00:00:00   Control  27   M 2015-08-07    2015.0
# 116774  1988-01-24 00:00:00   Control  17   M 2005-03-23    2005.0
# 116798  1988-09-04 00:00:00   Control  25   M 2014-12-15    2014.0
# 124273  1993-01-19 00:00:00   Control  12   M 2005-04-19    2005.0
#
#        Infertility  Psoriasis Tuberculosis Tuberculosis s/p  ...  \
# 485             NaT       NaN          NaT              NaT  ...
# 1840            NaT       NaN          NaT              NaT  ...
# 1317            NaT       NaN          NaT              NaT  ...
# 2923            NaT       NaN          NaT              NaT  ...
# 3805            NaT       NaN          NaT              NaT  ...
# ...             ...       ...          ...              ...  ...
# 115527   2008-03-01       NaN          NaT              NaT  ...
# 115551   2016-09-26       NaN          NaT              NaT  ...
# 116774   2013-03-18       NaN          NaT              NaT  ...
# 116798   2017-11-01       NaN          NaT              NaT  ...
# 124273   2017-10-09       NaN          NaT              NaT  ...
#
#        OncGenitalia_status_status Oncmyeloma_status_status  \
# 485                             1                        1
# 1840                            1                        1
# 1317                            1                        1
# 2923                            1                        1
# 3805                            1                        1
# ...                           ...                      ...
# 115527                          1                        1
# 115551                          1                        1
# 116774                          1                        1
# 116798                          1                        1
# 124273                          1                        1
#
#        OncPolycythemiaVera_status_status OncMyelodysplastic_status_status  \
# 485                                    1                                1
# 1840                                   1                                1
# 1317                                   1                                1
# 2923                                   1                                1
# 3805                                   1                                1
# ...                                  ...                              ...
# 115527                                 1                                1
# 115551                                 1                                1
# 116774                                 1                                1
# 116798                                 1                                1
# 124273                                 1                                1
#
#        OncLympholiferative_status_status OncNeurofibromatosis_status_status  \
# 485                                    1                                  1
# 1840                                   1                                  1
# 1317                                   1                                  1
# 2923                                   1                                  1
# 3805                                   1                                  1
# ...                                  ...                                ...
# 115527                                 1                                  1
# 115551                                 1                                  1
# 116774                                 1                                  1
# 116798                                 1                                  1
# 124273                                 1                                  1
#
#        OncOther_status_status OncUnKnow_status_status  \
# 485                         1                       1
# 1840                        1                       1
# 1317                        1                       1
# 2923                        1                       1
# 3805                        1                       1
# ...                       ...                     ...
# 115527                      1                       1
# 115551                      1                       1
# 116774                      1                       1
# 116798                      1                       1
# 124273                      1                       1
#
#        Infertility_Status_status_status Age at Infertile Diagnosis
# 485                                   1                        NaN
# 1840                                  1                        NaN
# 1317                                  1                        NaN
# 2923                                  1                        NaN
# 3805                                  1                        NaN
# ...                                 ...                        ...
# 115527                                1                       20.0
# 115551                                1                       28.0
# 116774                                1                       25.0
# 116798                                1                       29.0
# 124273                                1                       24.0
#
# [788 rows x 387 columns]

# %%
# considerare condizioni pre-esistenti alla diagnosi di infertilità
# Converting date columns to datetime for comparison
df_concatenated['Infertility '] = pd.to_datetime(df_concatenated['Infertility '], errors='coerce')


# Identify comorbidity columns, assuming they start from "Tuberculosis" onwards
comorbidity_columns = data.columns[data.columns.get_loc("Tuberculosis"):data.columns.get_loc('OncUnKnow')]

# Iterate through comorbidity columns to adjust dates
for column in comorbidity_columns:
    df_concatenated[column] = pd.to_datetime(df_concatenated[column], errors='coerce')
    # Replace the date with NaN if it occurs after the relevant reference date
    df_concatenated[column] = data.apply(
        lambda row: (
            row[column] if pd.isna(row[column]) or (
                pd.notna(row['Infertility '] and row[column] <= row['Infertility ']) or (
                pd.isna(row['Infertility ']) and ((pd.to_datetime(row[column]) - pd.to_datetime(row['date_of_birth'])).dt.days/365.25).astype(int) < row.age) 
            ) else pd.NaT
        ), 
        axis=1
    )

# %%
# Create binary variable for presence of infertility (Infertility_Status)
df_concatenated['Infertility_Status'] = np.where(df_concatenated['Infertility '].notna(), 1, 0)

# List of comorbidity columns to include in the logistic regression
comorbidity_columns = data.columns[data.columns.get_loc("Tuberculosis"):data.columns.get_loc('OncUnKnow')]

# To store the results of each regression
results = []

# Loop through each comorbidity to perform logistic regression
for comorbidity in comorbidity_columns:
    # Create binary variable for presence of comorbidity
    df_concatenated[comorbidity + '_status'] = df_concatenated[comorbidity].notna().astype(int)

    # Check for variability: skip if there is no or minimal variation
    count = df_concatenated[comorbidity + '_status'].sum()
    if count == 0 or count == len(df_concatenated) or count < 5:  # Skipping if too few positive cases
        continue

    # Define the independent variable (comorbidity) and the dependent variable (Infertility_Status)
    X = df_concatenated[[comorbidity + '_status']]
    y = df_concatenated['Infertility_Status']

    # Add an intercept to the independent variable
    X = sm.add_constant(X)

    try:
        # Fit the logistic regression model
        model = sm.Logit(y, X)
        result = model.fit(disp=False)

        # Calculate Odds Ratio for the comorbidity
        odds_ratio = np.exp(result.params[comorbidity + '_status'])
        ci = result.conf_int().loc[comorbidity + '_status']
        ci_odds_ratio = np.exp(ci)

        # Extract p-value for the comorbidity
        p_value = result.pvalues[comorbidity + '_status']

        # Append the results for the comorbidity
        results.append({
            'Comorbidity': comorbidity,
            'Odds Ratio': odds_ratio,
            '95% CI Lower': ci_odds_ratio[0],
            '95% CI Upper': ci_odds_ratio[1],
            'p-value': p_value
        })

    except np.linalg.LinAlgError:
        # Handle any singular matrix errors due to collinearity or insufficient data
        print(f"Skipping {comorbidity} due to singular matrix issue.")
        continue

# Convert the results to a DataFrame for better viewing
results_df = pd.DataFrame(results)

# Filter for statistically significant results at the 0.05 level
significant_results = results_df[results_df['p-value'] < 0.05]
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Skipping Hyperlipidemia due to singular matrix issue.
# Skipping other kidney Disease due to singular matrix issue.
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
significant_results
# Out:
# Empty DataFrame
# Columns: [Comorbidity, Odds Ratio, 95% CI Lower, 95% CI Upper, p-value]
# Index: []

# %% [markdown]
# ## Pazienti Infertili -Psoriasi

# %%
data = df[selected_columns]
data = data[data.sex == 'M']
data = data[data['Infertility '].notna()]
data
# Out:
#               date_of_birth  GroupName age sex    Start_D  DiagYear  \
# 836     1921-06-16 00:00:00  Psoriasis  92   M 2014-11-26    2014.0
# 1429    1923-06-05 00:00:00  Psoriasis  79   M 2003-11-30    2003.0
# 1592    1923-04-01 00:00:00    Control  82   M 2006-03-01    2006.0
# 1809    1924-06-20 00:00:00    Control  85   M 2010-10-03    2010.0
# 2522    1925-01-19 00:00:00  Psoriasis  83   M 2008-06-20    2008.0
# ...                     ...        ...  ..  ..        ...       ...
# 122421  1992-08-05 00:00:00  Psoriasis  14   M 2007-02-17    2007.0
# 124273  1993-01-19 00:00:00    Control  12   M 2005-04-19    2005.0
# 130280  2000-02-06 00:00:00  Psoriasis  14   M 2015-03-29    2015.0
# 130681  2000-04-13 00:00:00    Control  12   M 2013-04-21    2013.0
# 131334  2001-06-15 00:00:00  Psoriasis   9   M 2011-03-03    2011.0
#
#                Infertility             Psoriasis Tuberculosis  \
# 836     2006-02-03 00:00:00                  NaN          NaN
# 1429    2012-11-19 00:00:00  1998-08-01 00:00:00          NaN
# 1592    2004-09-17 00:00:00                  NaN          NaN
# 1809    2002-01-28 00:00:00                  NaN          NaN
# 2522    2004-12-19 00:00:00  2014-02-23 00:00:00          NaN
# ...                     ...                  ...          ...
# 122421  2012-03-01 00:00:00                  NaN          NaN
# 124273  2017-10-09 00:00:00                  NaN          NaN
# 130280  2000-02-06 00:00:00                  NaN          NaN
# 130681  2000-04-13 00:00:00                  NaN          NaN
# 131334  2002-01-29 00:00:00                  NaN          NaN
#
#            Tuberculosis s/p  ... OncBone          OncSaracoma OncGenitalia  \
# 836                     NaN  ...     NaN                  NaN          NaN
# 1429                    NaN  ...     NaN  2007-07-01 00:00:00          NaN
# 1592    1999-12-19 00:00:00  ...     NaN                  NaN          NaN
# 1809                    NaN  ...     NaN                  NaN          NaN
# 2522                    NaN  ...     NaN                  NaN          NaN
# ...                     ...  ...     ...                  ...          ...
# 122421                  NaN  ...     NaN                  NaN          NaN
# 124273                  NaN  ...     NaN                  NaN          NaN
# 130280                  NaN  ...     NaN                  NaN          NaN
# 130681                  NaN  ...     NaN                  NaN          NaN
# 131334                  NaN  ...     NaN                  NaN          NaN
#
#        Oncmyeloma  OncPolycythemiaVera OncMyelodysplastic  \
# 836           NaN                  NaN                NaN
# 1429          NaN                  NaN                NaN
# 1592          NaN  2004-09-01 00:00:00                NaN
# 1809          NaN                  NaN                NaN
# 2522          NaN                  NaN                NaN
# ...           ...                  ...                ...
# 122421        NaN                  NaN                NaN
# 124273        NaN                  NaN                NaN
# 130280        NaN                  NaN                NaN
# 130681        NaN                  NaN                NaN
# 131334        NaN                  NaN                NaN
#
#         OncLympholiferative OncNeurofibromatosis             OncOther  \
# 836     2012-08-22 00:00:00                  NaN                  NaN
# 1429                    NaN                  NaN  2012-08-19 00:00:00
# 1592                    NaN                  NaN                  NaN
# 1809                    NaN                  NaN                  NaN
# 2522                    NaN                  NaN                  NaN
# ...                     ...                  ...                  ...
# 122421                  NaN                  NaN                  NaN
# 124273                  NaN                  NaN                  NaN
# 130280                  NaN                  NaN                  NaN
# 130681                  NaN                  NaN                  NaN
# 131334                  NaN                  NaN                  NaN
#
#        OncUnKnow
# 836          NaN
# 1429         NaN
# 1592         NaN
# 1809         NaN
# 2522         NaN
# ...          ...
# 122421       NaN
# 124273       NaN
# 130280       NaN
# 130681       NaN
# 131334       NaN
#
# [802 rows x 133 columns]

# %%
data = data[
    ~((data['GroupName'] == 'Psoriasis') & (data['Psoriasis'].isna()))
]
data
# Out:
#               date_of_birth  GroupName age sex    Start_D  DiagYear  \
# 1429    1923-06-05 00:00:00  Psoriasis  79   M 2003-11-30    2003.0
# 1592    1923-04-01 00:00:00    Control  82   M 2006-03-01    2006.0
# 1809    1924-06-20 00:00:00    Control  85   M 2010-10-03    2010.0
# 2522    1925-01-19 00:00:00  Psoriasis  83   M 2008-06-20    2008.0
# 2792    1926-01-01 00:00:00    Control  82   M 2008-09-03    2008.0
# ...                     ...        ...  ..  ..        ...       ...
# 115551  1987-11-03 00:00:00    Control  27   M 2015-08-07    2015.0
# 116774  1988-01-24 00:00:00    Control  17   M 2005-03-23    2005.0
# 116798  1988-09-04 00:00:00    Control  25   M 2014-12-15    2014.0
# 124273  1993-01-19 00:00:00    Control  12   M 2005-04-19    2005.0
# 130681  2000-04-13 00:00:00    Control  12   M 2013-04-21    2013.0
#
#                Infertility             Psoriasis Tuberculosis  \
# 1429    2012-11-19 00:00:00  1998-08-01 00:00:00          NaN
# 1592    2004-09-17 00:00:00                  NaN          NaN
# 1809    2002-01-28 00:00:00                  NaN          NaN
# 2522    2004-12-19 00:00:00  2014-02-23 00:00:00          NaN
# 2792    2004-03-24 00:00:00                  NaN          NaN
# ...                     ...                  ...          ...
# 115551  2016-09-26 00:00:00                  NaN          NaN
# 116774  2013-03-18 00:00:00                  NaN          NaN
# 116798  2017-11-01 00:00:00                  NaN          NaN
# 124273  2017-10-09 00:00:00                  NaN          NaN
# 130681  2000-04-13 00:00:00                  NaN          NaN
#
#            Tuberculosis s/p  ... OncBone          OncSaracoma OncGenitalia  \
# 1429                    NaN  ...     NaN  2007-07-01 00:00:00          NaN
# 1592    1999-12-19 00:00:00  ...     NaN                  NaN          NaN
# 1809                    NaN  ...     NaN                  NaN          NaN
# 2522                    NaN  ...     NaN                  NaN          NaN
# 2792                    NaN  ...     NaN                  NaN          NaN
# ...                     ...  ...     ...                  ...          ...
# 115551                  NaN  ...     NaN                  NaN          NaN
# 116774                  NaN  ...     NaN                  NaN          NaN
# 116798                  NaN  ...     NaN                  NaN          NaN
# 124273                  NaN  ...     NaN                  NaN          NaN
# 130681                  NaN  ...     NaN                  NaN          NaN
#
#        Oncmyeloma  OncPolycythemiaVera OncMyelodysplastic OncLympholiferative  \
# 1429          NaN                  NaN                NaN                 NaN
# 1592          NaN  2004-09-01 00:00:00                NaN                 NaN
# 1809          NaN                  NaN                NaN                 NaN
# 2522          NaN                  NaN                NaN                 NaN
# 2792          NaN                  NaN                NaN                 NaN
# ...           ...                  ...                ...                 ...
# 115551        NaN                  NaN                NaN                 NaN
# 116774        NaN                  NaN                NaN                 NaN
# 116798        NaN                  NaN                NaN                 NaN
# 124273        NaN                  NaN                NaN                 NaN
# 130681        NaN                  NaN                NaN                 NaN
#
#        OncNeurofibromatosis             OncOther            OncUnKnow
# 1429                    NaN  2012-08-19 00:00:00                  NaN
# 1592                    NaN                  NaN                  NaN
# 1809                    NaN                  NaN                  NaN
# 2522                    NaN                  NaN                  NaN
# 2792                    NaN                  NaN                  NaN
# ...                     ...                  ...                  ...
# 115551                  NaN                  NaN                  NaN
# 116774                  NaN                  NaN                  NaN
# 116798                  NaN                  NaN  2010-09-07 00:00:00
# 124273                  NaN                  NaN                  NaN
# 130681                  NaN                  NaN                  NaN
#
# [502 rows x 133 columns]

# %%
data['Infertility '] = pd.to_datetime(data['Infertility '], errors='coerce')
data['Psoriasis'] = pd.to_datetime(data['Psoriasis'], errors='coerce')

# Filter patients where Infertility is before Psoriasis, but keep those with NaN in Psoriasis
data = data[(data['Psoriasis'].isna()) | (data['Infertility '] < data['Psoriasis'])]

# Display the filtered data
data
# Out:
# <ipython-input-106-2c6b41e7b901>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Infertility '] = pd.to_datetime(data['Infertility '], errors='coerce')
# <ipython-input-106-2c6b41e7b901>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Psoriasis'] = pd.to_datetime(data['Psoriasis'], errors='coerce')
#               date_of_birth  GroupName age sex    Start_D  DiagYear  \
# 1592    1923-04-01 00:00:00    Control  82   M 2006-03-01    2006.0
# 1809    1924-06-20 00:00:00    Control  85   M 2010-10-03    2010.0
# 2522    1925-01-19 00:00:00  Psoriasis  83   M 2008-06-20    2008.0
# 2792    1926-01-01 00:00:00    Control  82   M 2008-09-03    2008.0
# 3451    1927-04-10 00:00:00    Control  77   M 2005-09-12    2005.0
# ...                     ...        ...  ..  ..        ...       ...
# 115551  1987-11-03 00:00:00    Control  27   M 2015-08-07    2015.0
# 116774  1988-01-24 00:00:00    Control  17   M 2005-03-23    2005.0
# 116798  1988-09-04 00:00:00    Control  25   M 2014-12-15    2014.0
# 124273  1993-01-19 00:00:00    Control  12   M 2005-04-19    2005.0
# 130681  2000-04-13 00:00:00    Control  12   M 2013-04-21    2013.0
#
#        Infertility   Psoriasis Tuberculosis     Tuberculosis s/p  ... OncBone  \
# 1592     2004-09-17        NaT          NaN  1999-12-19 00:00:00  ...     NaN
# 1809     2002-01-28        NaT          NaN                  NaN  ...     NaN
# 2522     2004-12-19 2014-02-23          NaN                  NaN  ...     NaN
# 2792     2004-03-24        NaT          NaN                  NaN  ...     NaN
# 3451     2003-02-02        NaT          NaN                  NaN  ...     NaN
# ...             ...        ...          ...                  ...  ...     ...
# 115551   2016-09-26        NaT          NaN                  NaN  ...     NaN
# 116774   2013-03-18        NaT          NaN                  NaN  ...     NaN
# 116798   2017-11-01        NaT          NaN                  NaN  ...     NaN
# 124273   2017-10-09        NaT          NaN                  NaN  ...     NaN
# 130681   2000-04-13        NaT          NaN                  NaN  ...     NaN
#
#        OncSaracoma OncGenitalia Oncmyeloma  OncPolycythemiaVera  \
# 1592           NaN          NaN        NaN  2004-09-01 00:00:00
# 1809           NaN          NaN        NaN                  NaN
# 2522           NaN          NaN        NaN                  NaN
# 2792           NaN          NaN        NaN                  NaN
# 3451           NaN          NaN        NaN  2010-04-01 00:00:00
# ...            ...          ...        ...                  ...
# 115551         NaN          NaN        NaN                  NaN
# 116774         NaN          NaN        NaN                  NaN
# 116798         NaN          NaN        NaN                  NaN
# 124273         NaN          NaN        NaN                  NaN
# 130681         NaN          NaN        NaN                  NaN
#
#        OncMyelodysplastic OncLympholiferative OncNeurofibromatosis OncOther  \
# 1592                  NaN                 NaN                  NaN      NaN
# 1809                  NaN                 NaN                  NaN      NaN
# 2522                  NaN                 NaN                  NaN      NaN
# 2792                  NaN                 NaN                  NaN      NaN
# 3451                  NaN                 NaN                  NaN      NaN
# ...                   ...                 ...                  ...      ...
# 115551                NaN                 NaN                  NaN      NaN
# 116774                NaN                 NaN                  NaN      NaN
# 116798                NaN                 NaN                  NaN      NaN
# 124273                NaN                 NaN                  NaN      NaN
# 130681                NaN                 NaN                  NaN      NaN
#
#                   OncUnKnow
# 1592                    NaN
# 1809                    NaN
# 2522                    NaN
# 2792                    NaN
# 3451                    NaN
# ...                     ...
# 115551                  NaN
# 116774                  NaN
# 116798  2010-09-07 00:00:00
# 124273                  NaN
# 130681                  NaN
#
# [453 rows x 133 columns]

# %%
# Filter comorbidities to only include those diagnosed before the infertility diagnosis
comorbidity_columns = data.columns[data.columns.get_loc("Tuberculosis"):]  # Assuming comorbidities start from "Tuberculosis"

# Iterate through comorbidity columns to adjust dates
for column in comorbidity_columns:
    data[column] = pd.to_datetime(data[column], errors='coerce')
    # Replace comorbidity dates with NaN if diagnosed after infertility
    data[column] = data.apply(
        lambda row: row[column] if pd.isna(row[column]) or (row[column] <= row['Infertility ']) else pd.NaT,
        axis=1
    )

# Create binary variable for psoriasis status: 1 for Psoriatic, 0 for Non-Psoriatic
data['Psoriasis_Status'] = data['Psoriasis'].notna().astype(int)

# To store the results of each regression
results = []

# Loop through each comorbidity to perform logistic regression
for comorbidity in comorbidity_columns:
    # Create binary variable for presence of comorbidity
    data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)

    # Check for variability: skip if there is no or minimal variation
    count = data[comorbidity + '_status'].sum()
    if count == 0 or count == len(data) or count < 5:  # Skipping if too few positive cases
        continue

    # Define the independent variable (comorbidity) and the dependent variable (Psoriasis_Status)
    X = data[[comorbidity + '_status']]
    y = data['Psoriasis_Status']

    # Add an intercept to the independent variable
    X = sm.add_constant(X)

    try:
        # Fit the logistic regression model
        model = sm.Logit(y, X)
        result = model.fit(disp=False)

        # Calculate Odds Ratio for the comorbidity
        odds_ratio = np.exp(result.params[comorbidity + '_status'])
        ci = result.conf_int().loc[comorbidity + '_status']
        ci_odds_ratio = np.exp(ci)

        # Extract p-value for the comorbidity
        p_value = result.pvalues[comorbidity + '_status']

        # Append the results for the comorbidity
        results.append({
            'Comorbidity': comorbidity,
            'Odds Ratio': odds_ratio,
            '95% CI Lower': ci_odds_ratio[0],
            '95% CI Upper': ci_odds_ratio[1],
            'p-value': p_value
        })

    except np.linalg.LinAlgError:
        # Handle any singular matrix errors due to collinearity or insufficient data
        print(f"Skipping {comorbidity} due to singular matrix issue.")
        continue

# Convert the results to a DataFrame for better viewing
results_df = pd.DataFrame(results)

# Filter for statistically significant results at the 0.05 level
significant_results = results_df[results_df['p-value'] < 0.001]
# Out:
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data.apply(
# <ipython-input-109-c9171c2dd6ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_datetime(data[column], errors='coerce')
# <ipython-input-109-c9171c2dd6ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)
# <ipython-input-109-c9171c2dd6ba>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[comorbidity + '_status'] = data[comorbidity].notna().astype(int)

# %%
significant_results
# Out:
# Empty DataFrame
# Columns: [Comorbidity, Odds Ratio, 95% CI Lower, 95% CI Upper, p-value]
# Index: []
